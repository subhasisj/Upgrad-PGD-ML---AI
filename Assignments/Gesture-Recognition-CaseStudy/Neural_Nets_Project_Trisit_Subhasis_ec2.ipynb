# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %% [markdown]
#                                                                                                - Trisit Kumar Chatterjee
#                                                                                                - Subhasis Jethy

# %%
# import important libraries
import numpy as np
import pandas as pd
import os
#from scipy.misc import imread, imresize

from skimage.io import imread
from skimage.transform import resize as imresize
import cv2
import matplotlib.pyplot as plt
import datetime

# %%
# Import all the required Keras modules
from tensorflow.keras.models import Sequential, Model, load_model
from tensorflow.keras.layers import GlobalAveragePooling2D, Input, Flatten, BatchNormalization, Activation, Dropout
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Dense, GRU, Flatten, TimeDistributed
from tensorflow.keras.layers import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras import optimizers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import LeakyReLU
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow.keras import backend as K
import tensorflow as tf
tf.random.set_seed(30) # Corrected
tf.__version__
# Out:
# '2.1.3'

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('./Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('./Project_data/val.csv').readlines())
batch_size = 32#experiment with the batch size

# %%
train_path = './Project_data/train' # To be used as source_path in generator function
val_path = './Project_data/val'

# %% [markdown]
# ## EDA - Analysis of the Images to see the size and augmentation requirements
#
# - All the images present in the folder are of size either 120x160x3 or 360x360x3.
# - So they have to be brought to same size i.e. bring them to size 120x120x3 or 100x100x3 as necessary

# %%
# Create a seperate data frame of train data for EDA
train_df = pd.read_csv('./Project_data/train.csv',header = None)
train_df = train_df[0].str.split(pat = ';',expand = True)
train_df.rename(columns = {0: 'Name', 1: 'Gesture', 2: 'Class'},inplace = True)
train_df.sample(n=5, random_state=30)
# Out:
#                                           Name          Gesture Class
# 152  WIN_20180926_16_54_08_Pro_Right_Swipe_new  Right_Swipe_new     1
# 314  WIN_20180925_18_02_58_Pro_Thumbs_Down_new  Thumbs_Down_new     3
# 12    WIN_20180925_17_33_08_Pro_Left_Swipe_new   Left_Swipe_new     0
# 413    WIN_20180925_17_51_17_Pro_Thumbs_Up_new    Thumbs_Up_new     4
# 74    WIN_20180926_17_17_35_Pro_Left_Swipe_new   Left_Swipe_new     0

# %%
# Check for class imbalance
train_df['Class'].value_counts()
# Out:
# 3    137
# 1    137
# 0    136
# 2    130
# 4    123
# Name: Class, dtype: int64

# %% [markdown]
# - One can see good fair distribution of videos for every class. So all five classes are well balanced

# %%
# Let us see images are of which shape. It will help us in reshaping all of them to the same size
shape_120_160 = 0
shape_360_360 = 0
shape_rest = 0

for folder in train_df['Name']:
    temp = os.listdir('./Project_data/train'+'/'+ folder)
    if(imread('./Project_data/train'+'/'+ folder +'/'+temp[2]).shape == (120,160,3)):
        shape_120_160 += 1
    elif(imread('./Project_data/train'+'/'+ folder +'/'+temp[2]).shape == (360,360,3)):
        shape_360_360 += 1
    else:
        shape_rest += 1
         
print('Number of images with shape 120x160x3:', shape_120_160)
print('Number of images with shape 360x360x3:', shape_360_360)
print('Number of images with other shapes   :', shape_rest)
# Out:
# Number of images with shape 120x160x3: 479
# Number of images with shape 360x360x3: 184
# Number of images with other shapes   : 0

# %% [markdown]
# - As one can see images are either of 120x160x3 or 360x360x3 shape
# - They will be reshaped to 120x120x3 or 100x100x3 as necessary later in the code

# %%
# This is a custom function to show the images and their augmentation
def imageview(class_img, source_path):
    
    # Get all 30 images in the folder
    images = os.listdir(source_path+'/'+ class_img)
    # Select one image (I have chosen 25th image) among the 30 images
    image = imread(source_path+'/'+ class_img +'/'+images[24])
    print('original:',image.shape)
    
    # Resize the image
    resized_img = cv2.resize(image, (120,120), interpolation = cv2.INTER_AREA)
    print('resized:',resized_img.shape)
    
    # Apply Gaussian Blur on the image
    blur_image = cv2.GaussianBlur(resized_img, (3,3), 3)
    print('blurred:',blur_image.shape)
    
    # Image Edge Detection
    edge_image = cv2.Canny(blur_image, 75, 150)
    # Get it into shape of 120x120x3 to maintain same shape through out (Canny removes the channels)
    edge_image1 = cv2.cvtColor(edge_image, cv2.COLOR_GRAY2BGR)
    print('edge:',edge_image1.shape)
    
    # Normalize the image
    norm_img = resized_img/255
    print('normalized:',norm_img.shape)
    
    fig = plt.figure(figsize = (20, 30))
    
    plt.subplot(151)
    plt.title('Original')
    plt.imshow(image)
    
    plt.subplot(152)
    plt.title('Resized')
    plt.imshow(resized_img) 
     
    plt.subplot(153)
    plt.title('Gaussian Blur')
    plt.imshow(blur_image)
    
    plt.subplot(154)
    plt.title('Edges')
    plt.imshow(edge_image1, cmap = 'gray')
    
    plt.subplot(155)
    plt.title('Normalized')
    plt.imshow(norm_img)

    plt.show()

# %%
# Consider two images (one with 120x160x3 and another with 360x360x3) each from every class for analysis
class_0_120 = train_df[train_df['Class']=='0'].reset_index()['Name'][2]
class_0_360 = train_df[train_df['Class']=='0'].reset_index()['Name'][133]
class_1_120 = train_df[train_df['Class']=='1'].reset_index()['Name'][0]
class_1_360 = train_df[train_df['Class']=='1'].reset_index()['Name'][131]
class_2_120 = train_df[train_df['Class']=='2'].reset_index()['Name'][1]
class_2_360 = train_df[train_df['Class']=='2'].reset_index()['Name'][121]
class_3_120 = train_df[train_df['Class']=='3'].reset_index()['Name'][1]
class_3_360 = train_df[train_df['Class']=='3'].reset_index()['Name'][130]
class_4_120 = train_df[train_df['Class']=='4'].reset_index()['Name'][5]
class_4_360 = train_df[train_df['Class']=='4'].reset_index()['Name'][111]

# %%
# View the images with their augmented outputs
print('\033[1m' + 'Image for Swipe Left:' + '\033[0m')
imageview(class_0_120, './Project_data/train')
imageview(class_0_360, './Project_data/train')
print('\033[1m' + 'Image for Swipe Right:' + '\033[0m')
imageview(class_1_120, './Project_data/train')
imageview(class_1_360, './Project_data/train')
print('\033[1m' + 'Image for Stop:' + '\033[0m')
imageview(class_2_120, './Project_data/train')
imageview(class_2_360, './Project_data/train')
print('\033[1m' + 'Image for Volume Down:' + '\033[0m')
imageview(class_3_120, './Project_data/train')
imageview(class_3_360, './Project_data/train')
print('\033[1m' + 'Image for Volume Up:' + '\033[0m')
imageview(class_4_120, './Project_data/train')
imageview(class_4_360, './Project_data/train')
# Out:
# Image for Swipe Left:
# original: (120, 160, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# original: (360, 360, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# Image for Swipe Right:
# original: (120, 160, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# original: (360, 360, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# Image for Stop:
# original: (120, 160, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# original: (360, 360, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# Image for Volume Down:
# original: (120, 160, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# original: (360, 360, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# Image for Volume Up:
# original: (120, 160, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)
# original: (360, 360, 3)
# resized: (120, 120, 3)
# blurred: (120, 120, 3)
# edge: (120, 120, 3)
# normalized: (120, 120, 3)

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
# The generator function
def generator(source_path, folder_list, batch_size, num_frames, frame_height, frame_width, augment, normalize):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    
    # Based on the number of frames, some frames can be skipped in between. Use linspace function to do that
    img_idx = np.round(np.linspace(0, 29, num_frames)).astype(int) #create a list of image numbers you want to use for a particular video
    print("Image Indexes: ", img_idx)
    while True:
        t           = np.random.permutation(folder_list)
        num_batches = int(len(t)//batch_size) # calculate the number of batches
        for batch in range(num_batches):      # we iterate over the number of batches
            
            batch_data      = np.zeros((batch_size, num_frames, frame_height, frame_width, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels    = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
            batch_data_blur = np.zeros((batch_size, num_frames, frame_height, frame_width, 3))
            batch_data_edge = np.zeros((batch_size, num_frames, frame_height, frame_width, 3))           
            
            for folder in range(batch_size): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate over the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # Resize the Images maintaining the aspect ratio
                    image_resized = cv2.resize(image, (frame_height,frame_width), interpolation = cv2.INTER_AREA)
                    
                    if(normalize == True):
                        batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255.0 #normalise and feed in the image
                        batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255.0 #normalise and feed in the image
                        batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255.0 #normalise and feed in the image       
                    else:
                        batch_data[folder,idx,:,:,0] = (image_resized[:,:,0]) #normalise and feed in the image
                        batch_data[folder,idx,:,:,1] = (image_resized[:,:,1]) #normalise and feed in the image
                        batch_data[folder,idx,:,:,2] = (image_resized[:,:,2]) #normalise and feed in the image                          
                    
                    # Add augmentation (Gaussian Noise Images)
                    if (augment == True):                
                        # Add blurred images
                        image_blur = cv2.GaussianBlur(image_resized,(3,3),3)
                        if(normalize == True):
                            batch_data_blur[folder,idx,:,:,0] = (image_blur[:,:,0])/255 #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,1] = (image_blur[:,:,1])/255 #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,2] = (image_blur[:,:,2])/255 #normalise and feed in the image
                        else:
                            batch_data_blur[folder,idx,:,:,0] = (image_blur[:,:,0]) #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,1] = (image_blur[:,:,1]) #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,2] = (image_blur[:,:,2]) #normalise and feed in the image                          
                  
                batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
            if(augment == True):
                # Add blurred images to the data
                batch_data    = np.concatenate([batch_data, batch_data_blur])
                batch_labels  = np.concatenate([batch_labels, batch_labels])
            
            yield batch_data, batch_labels #you yield the batch_data and the batch_labels, remember what does yield do
        
        # write the code for the remaining data points which are left after full batches
        remaining_data = len(t) % batch_size
        if(remaining_data != 0):
            
            batch_data = np.zeros((remaining_data, num_frames, frame_height, frame_width, 3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
            batch_labels    = np.zeros((remaining_data,5))                                    # batch_labels is the one hot representation of the output
            batch_data_blur = np.zeros((remaining_data, num_frames, frame_height, frame_width, 3))
            batch_data_edge = np.zeros((remaining_data, num_frames, frame_height, frame_width, 3))           

            for folder in range(remaining_data): # iterate over the batch_size
                imgs = os.listdir(source_path+'/'+ t[folder + (num_batches*batch_size)].split(';')[0]) # read all the images in the folder
                for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
                    image = imread(source_path+'/'+ t[folder + (num_batches*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                    
                    #crop the images and resize them. Note that the images are of 2 different shape 
                    #and the conv3D will throw error if the inputs in a batch have different shapes
                    # Resize the Images maintaining the aspect ratio
                    image_resized = cv2.resize(image, (frame_height,frame_width), interpolation = cv2.INTER_AREA)
                    
                    if(normalize == True):
                        batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255.0 #normalise and feed in the image
                        batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255.0 #normalise and feed in the image
                        batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255.0 #normalise and feed in the image       
                    else:
                        batch_data[folder,idx,:,:,0] = (image_resized[:,:,0]) #normalise and feed in the image
                        batch_data[folder,idx,:,:,1] = (image_resized[:,:,1]) #normalise and feed in the image
                        batch_data[folder,idx,:,:,2] = (image_resized[:,:,2]) #normalise and feed in the image     
                    
                    # Add augmentation (Gaussian Noise Images)
                    if(augment == True):
                        # Add blurred images
                        image_blur = cv2.GaussianBlur(image_resized,(3,3),3)

                        if(normalize == True):
                            batch_data_blur[folder,idx,:,:,0] = (image_blur[:,:,0])/255 #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,1] = (image_blur[:,:,1])/255 #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,2] = (image_blur[:,:,2])/255 #normalise and feed in the image
                        else:
                            batch_data_blur[folder,idx,:,:,0] = (image_blur[:,:,0]) #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,1] = (image_blur[:,:,1]) #normalise and feed in the image
                            batch_data_blur[folder,idx,:,:,2] = (image_blur[:,:,2]) #normalise and feed in the image    

                batch_labels[folder, int(t[folder + (num_batches*batch_size)].strip().split(';')[2])] = 1

            if(augment == True):
                # Add blurred images to the data
                batch_data = np.concatenate([batch_data, batch_data_blur])
                batch_labels = np.concatenate([batch_labels, batch_labels])

            yield batch_data, batch_labels

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %% [markdown]
# ### Test the Generator Function

# %%
# Test the Generator function on training data set

num_frames    = 20 
frame_height  = 120
frame_width   = 120
augment       = False
normalize     = True

train_generator = generator(train_path, train_doc, batch_size, num_frames, frame_height, frame_width, augment, normalize)

for i in range(int(len(train_doc)//batch_size + 1)):
    batch_data_temp, batch_label_temp = next(train_generator)
    print('Shape of each batch: ',batch_data_temp.shape)
    print('Shape of each batch label: ',batch_label_temp.shape)
# Out:
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  3  5  6  8  9 11 12 14 15 17 18 20 21 23 24 26 27 29]
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (23, 20, 120, 120, 3)
# Shape of each batch label:  (23, 5)

# %%
# Test the Generator function on validation data set

num_frames    = 20
frame_height  = 120
frame_width   = 120
augment       = False
normalize     = True

val_generator = generator(val_path, val_doc, batch_size, num_frames, frame_height, frame_width, augment, normalize)

if (len(val_doc)%batch_size) == 0:
    for i in range(int(len(val_doc)/batch_size)):
        batch_data_temp, batch_label_temp = next(val_generator)
        print('Shape of each batch: ',batch_data_temp.shape)
        print('Shape of each batch label: ',batch_label_temp.shape)        
else:
    for i in range(int(len(val_doc)//batch_size + 1)):
        batch_data_temp, batch_label_temp = next(val_generator)
        print('Shape of each batch: ',batch_data_temp.shape)
        print('Shape of each batch label: ',batch_label_temp.shape)
# Out:
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  3  5  6  8  9 11 12 14 15 17 18 20 21 23 24 26 27 29]
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (32, 20, 120, 120, 3)
# Shape of each batch label:  (32, 5)
# Shape of each batch:  (4, 20, 120, 120, 3)
# Shape of each batch label:  (4, 5)

# %%
curr_dt_time = datetime.datetime.now()
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 30 # choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 30

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %% [markdown]
# ### Custom functions
#
# Let us write some custom functions first which need to be repeatedly called
# 1. **generator()** function which is already written above
# 2. **trainer()** function to fit and train the model and calculate its accuracy and loss
# 3. **modelplot()** to plot the model accuracy and losses

# %%
# Function to fit and train the Model
def trainer(model, model_name, num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize):
    #normalize = normalize
    # Model with the training data
    train_gen = generator(train_path, train_doc, size_batch, num_frames, frame_height, frame_width, augment, normalize)
    # Calculate steps per epoch
    if (len(train_doc)%size_batch) == 0:
        train_steps_per_epoch = int(len(train_doc)/size_batch)
    else:
        train_steps_per_epoch = (len(train_doc)//size_batch) + 1

    # Model with validation data (Augmentation is not applied on the validation data set)
    augment = False
    val_gen = generator(val_path, val_doc, size_batch, num_frames, frame_height, frame_width, augment, normalize)
    # Calculate steps per epoch
    if (len(val_doc)%size_batch) == 0:
        val_steps_per_epoch = int(len(val_doc)/size_batch)
    else:
        val_steps_per_epoch = (len(val_doc)//size_batch) + 1

    # Callback function to save models   
    curr_dt_time = datetime.datetime.now() # Current date and time to store the models with timestamp
    mod_name = model_name + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    if not os.path.exists(mod_name):
        os.mkdir(mod_name)        
    filepath = mod_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

    checkpoint = ModelCheckpoint(filepath, monitor='val_categorical_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)        
        
    # Callback function to reduce learning rate upon reaching a plateau
    LR = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.2, patience = 4, verbose = 1) # write the REducelronplateau code here
    
    # Early Stop callback function
    earlystop = EarlyStopping(monitor = "val_loss", mode='auto', patience = 10, verbose = 1)
    
    # List of all callback functions
    callbacks_list = [checkpoint, LR, earlystop]

    # Fit the model
    history_obj = model.fit_generator(train_gen, steps_per_epoch = train_steps_per_epoch, 
                                      epochs = num_epochs, verbose = 1,
                                      callbacks = callbacks_list, workers = 1, 
                                      initial_epoch = 0, class_weight = None,
                                      validation_data = val_gen, 
                                      validation_steps = val_steps_per_epoch)                                        
  
    return history_obj

# %%
# Custom function for plotting accuracies and losses of the model
def modelplot(history):
    
    fig = plt.figure(figsize = (16, 5))
    
    # Plot the loss
    plt.subplot(121)
    plt.title('Loss')
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.legend(['train_loss','val_loss'])
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    
    # Plot the accuracy
    plt.subplot(122)
    plt.title('Accuracy')
    plt.plot(history.history['categorical_accuracy'])
    plt.plot(history.history['val_categorical_accuracy'])
    plt.legend(['train_categorical_accuracy','val_categorical_accuracy'])
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    
    plt.show()

# %%
# print(just to give an error)

# %% [markdown]
# ### Sample Model to Test
# - Write a sample model to decide the batch size, image size and number of frames

# %%
# Test Conv3D Model for test run
def model_Conv3D_Test(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(Conv3D(16, (3,3,3), 
                     input_shape = (num_frames, frame_height, frame_width, 3),     
                     padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(3,3,3)))
    
    model.add(Conv3D(32, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(64, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(128, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Flatten())

    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))
    
    # Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    
    return model

# %% [markdown]
# ### Deciding the batch size, image size and number of frames
#
# Time taken and the memory needed to train the model is greatly affected by the batch size, image size and number of frames. We do as below:
# - Experiment with different batch size till we hit the OOM error of GPU
# - Let us try three image sizes - 100x100, 120x120 and 160x160
# - Choose appropriate number of frames

# %% [markdown]
# #### Choosing Batch Size
#
# - We choose the batch size as 32 and number of frames as 24 to avoid OOM error
# - However, depending on the model architecture we may change thi if needed

# %%
# Model with image size 100x100

num_frames    = 24
frame_height  = 100
frame_width   = 100
batch_size    = 32
num_epochs    = 2
augment       = False # Add Gaussian Blurring taken care in Generator function
normalize     = True  # Diving image channel wise by 255 taken care in Generator function

model = model_Conv3D_Test(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam() 
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
trainer(model, 'Conv3D_Test', num_epochs, batch_size, num_frames, frame_height, frame_width, augment, normalize)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_2 (Conv3D)            (None, 24, 100, 100, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 24, 100, 100, 16)  0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 24, 100, 100, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 8, 33, 33, 16)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 8, 33, 33, 32)     4128
# _________________________________________________________________
# activation_1 (Activation)    (None, 8, 33, 33, 32)     0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 8, 33, 33, 32)     128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 4, 16, 16, 32)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 4, 16, 16, 64)     16448
# _________________________________________________________________
# activation_2 (Activation)    (None, 4, 16, 16, 64)     0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 16, 16, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 2, 8, 8, 64)       0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 2, 8, 8, 128)      65664
# _________________________________________________________________
# activation_3 (Activation)    (None, 2, 8, 8, 128)      0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 2, 8, 8, 128)      512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 4, 4, 128)      0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_5 (Activation)    (None, 5)                 0
# =================================================================
# Total params: 615,365
# Trainable params: 614,373
# Non-trainable params: 992
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# WARNING:tensorflow:From <ipython-input-17-7901921eb145>:45: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  1  3  4  5  6  8  9 10 11 13 14 15 16 18 19 20 21 23 24 25 26 28 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  1  3  4  5  6  8  9 10 11 13 14 15 16 18 19 20 21 23 24 25 26 28 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/2
# 20/21 [===========================>..] - ETA: 2s - loss: 1.3222 - categorical_accuracy: 0.5203
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21000, saving model to Conv3D_Test_2021-05-2412_25_45.931316/model-00001-1.31436-0.52036-2.37151-0.21000.h5
# 21/21 [==============================] - 53s 3s/step - loss: 1.3116 - categorical_accuracy: 0.5204 - val_loss: 2.3715 - val_categorical_accuracy: 0.2100
# Epoch 2/2
# 20/21 [===========================>..] - ETA: 2s - loss: 0.6309 - categorical_accuracy: 0.7406
# Epoch 00002: val_categorical_accuracy did not improve from 0.21000
# 21/21 [==============================] - 55s 3s/step - loss: 0.6365 - categorical_accuracy: 0.7406 - val_loss: 3.2086 - val_categorical_accuracy: 0.1800

# %%
# Model with image size 120x120
 
num_frames    = 24
frame_height  = 120
frame_width   = 120
size_batch    = 32
num_epochs    = 2
augment       = False
normalize     = True

model = model_Conv3D_Test(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam() 
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
trainer(model, 'Conv3D_Test', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_6 (Conv3D)            (None, 24, 120, 120, 16)  1312
# _________________________________________________________________
# activation_6 (Activation)    (None, 24, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 8, 40, 40, 16)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 8, 40, 40, 32)     4128
# _________________________________________________________________
# activation_7 (Activation)    (None, 8, 40, 40, 32)     0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 8, 40, 40, 32)     128
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 4, 20, 20, 32)     0
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 4, 20, 20, 64)     16448
# _________________________________________________________________
# activation_8 (Activation)    (None, 4, 20, 20, 64)     0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 20, 20, 64)     256
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 2, 10, 10, 64)     0
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 2, 10, 10, 128)    65664
# _________________________________________________________________
# activation_9 (Activation)    (None, 2, 10, 10, 128)    0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2, 10, 10, 128)    512
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 1, 5, 5, 128)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               819456
# _________________________________________________________________
# activation_10 (Activation)   (None, 256)               0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_11 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 910,277
# Trainable params: 909,285
# Non-trainable params: 992
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  1  3  4  5  6  8  9 10 11 13 14 15 16 18 19 20 21 23 24 25 26 28 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  1  3  4  5  6  8  9 10 11 13 14 15 16 18 19 20 21 23 24 25 26 28 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/2
# 20/21 [===========================>..] - ETA: 2s - loss: 1.3361 - categorical_accuracy: 0.5297
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21000, saving model to Conv3D_Test_2021-05-2412_27_44.817898/model-00001-1.32362-0.53092-1.74868-0.21000.h5
# 21/21 [==============================] - 54s 3s/step - loss: 1.3192 - categorical_accuracy: 0.5309 - val_loss: 1.7487 - val_categorical_accuracy: 0.2100
# Epoch 2/2
# 20/21 [===========================>..] - ETA: 2s - loss: 0.5979 - categorical_accuracy: 0.7766
# Epoch 00002: val_categorical_accuracy did not improve from 0.21000
# 21/21 [==============================] - 56s 3s/step - loss: 0.5958 - categorical_accuracy: 0.7798 - val_loss: 5.0693 - val_categorical_accuracy: 0.1700

# %%
# # Model with image size 160x160
 
# num_frames    = 8
# frame_height  = 160
# frame_width   = 160
# size_batch    = 24
# num_epochs    = 2
# augment       = False
# normalize     = True  # Diving image channel wise by 255 taken care in Generator function

# model = model_Conv3D_Test(num_frames, frame_height, frame_width)
# optimiser = optimizers.Adam() 
# model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
# print(model.summary())
# # Run the model and check accuracy
# trainer(model, 'Conv3D_Test', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)

# %% [markdown]
# - image with size 160x160 was also tested; however runs into OOM error with higher frame count
# - As it can be seen **`120x120` size** seemed better as it takes lesser time and at the same time gives good accuracy.
# - It is a good balance between time and accuracy.
# - It also helps us to choose higher batch size
# - We will start with this batch size but we will check further on **`100x100` size** as well in some models

# %% [markdown]
# #### Choose number of frames
#
# - We went ahead with one thought: Even one single image is capable enough to determine whether it is a Thumbs Up, Thumbs Down or Stop. For identifying Left and Right Swipes, we need at the most two images. This means we can manage with a smaller number of frames instead of all 30. So, **we chose 16 as the number of frames** (
# - This also helps us to tackle overfitting.

# %% [markdown]
# As these parameters are decided let us start building the model and decide on other parameters such as filter size, layers etc

# %% [markdown]
# ### Model Architecture 1 - Conv3D model with filter size (3,3,3)
#
# - We will start with a smaller number of epochs (20) in the beginning till we get all the parameters we need
# - We use Conv3D filters of 16,32,64,128 in increasing order and dense layer of 128 and 256

# %%
def model_Conv3D_1(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(Conv3D(16, (3,3,3), 
                     input_shape = (num_frames, frame_height, frame_width, 3),     
                     padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2,2,2)))
    
    model.add(Conv3D(32, (3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(64, (3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(128, (3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Flatten())

    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    
    # Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    
    return model

# %%
# Model 1 - Conv3D Model with filter size (3,3,3)

frame_height    = 120
frame_width     = 120
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = False
normalize       = True

model = model_Conv3D_1(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
modelplot(model_history)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_10 (Conv3D)           (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_14 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_15 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               802944
# _________________________________________________________________
# activation_16 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_17 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_18 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 1,130,565
# Trainable params: 1,129,829
# Non-trainable params: 736
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.3985 - categorical_accuracy: 0.4094
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21000, saving model to Conv3D_1_2021-05-2412_29_59.894663/model-00001-1.39094-0.41478-1.62059-0.21000.h5
# 21/21 [==============================] - 37s 2s/step - loss: 1.3883 - categorical_accuracy: 0.4148 - val_loss: 1.6206 - val_categorical_accuracy: 0.2100
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.0318 - categorical_accuracy: 0.5969
# Epoch 00002: val_categorical_accuracy improved from 0.21000 to 0.38000, saving model to Conv3D_1_2021-05-2412_29_59.894663/model-00002-1.02803-0.59729-2.31069-0.38000.h5
# 21/21 [==============================] - 37s 2s/step - loss: 1.0267 - categorical_accuracy: 0.5973 - val_loss: 2.3107 - val_categorical_accuracy: 0.3800
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.7588 - categorical_accuracy: 0.7125
# Epoch 00003: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 36s 2s/step - loss: 0.7647 - categorical_accuracy: 0.7119 - val_loss: 3.1373 - val_categorical_accuracy: 0.3100
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.6103 - categorical_accuracy: 0.7844
# Epoch 00004: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 36s 2s/step - loss: 0.6165 - categorical_accuracy: 0.7798 - val_loss: 2.9171 - val_categorical_accuracy: 0.1500
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.4853 - categorical_accuracy: 0.8281
# Epoch 00005: val_categorical_accuracy did not improve from 0.38000
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 36s 2s/step - loss: 0.4879 - categorical_accuracy: 0.8250 - val_loss: 4.5883 - val_categorical_accuracy: 0.2200
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3317 - categorical_accuracy: 0.8891
# Epoch 00006: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 37s 2s/step - loss: 0.3547 - categorical_accuracy: 0.8869 - val_loss: 3.5434 - val_categorical_accuracy: 0.2700
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3081 - categorical_accuracy: 0.9000
# Epoch 00007: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 36s 2s/step - loss: 0.3034 - categorical_accuracy: 0.9005 - val_loss: 3.4275 - val_categorical_accuracy: 0.2700
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2321 - categorical_accuracy: 0.9391
# Epoch 00008: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 36s 2s/step - loss: 0.2374 - categorical_accuracy: 0.9382 - val_loss: 4.9290 - val_categorical_accuracy: 0.2600
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2093 - categorical_accuracy: 0.9453
# Epoch 00009: val_categorical_accuracy did not improve from 0.38000
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 36s 2s/step - loss: 0.2092 - categorical_accuracy: 0.9457 - val_loss: 4.8122 - val_categorical_accuracy: 0.2200
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1634 - categorical_accuracy: 0.9688
# Epoch 00010: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 36s 2s/step - loss: 0.1592 - categorical_accuracy: 0.9698 - val_loss: 4.7262 - val_categorical_accuracy: 0.2200
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1458 - categorical_accuracy: 0.9766
# Epoch 00011: val_categorical_accuracy did not improve from 0.38000
# 21/21 [==============================] - 37s 2s/step - loss: 0.1485 - categorical_accuracy: 0.9759 - val_loss: 5.1805 - val_categorical_accuracy: 0.2300
# Epoch 00011: early stopping

# %% [markdown]
# - As one can see, **Model 1 is clearly overfitting**
# - Let us see if the kernel size (2,2,2) solves the overfitting problem

# %% [markdown]
# ### Model Architecture 2 - Conv3D model with filter size (2,2,2)

# %%
# Model 2 - Conv3D Model with filter size (2,2,2)
def model_Conv3D_2(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(Conv3D(16, (2,2,2), 
                     input_shape = (num_frames, frame_height, frame_width, 3),     
                     padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2,2,2)))
    
    model.add(Conv3D(32, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(64, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(128, (2, 2, 2), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Flatten())

    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    
    # Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    
    return model

# %%
# Model 2 - Conv3D Model with filter size (2,2,2)

frame_height    = 120
frame_width     = 120
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = False
normalization   = True

model = model_Conv3D_2(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_2', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_14 (Conv3D)           (None, 16, 120, 120, 16)  400
# _________________________________________________________________
# activation_19 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 8, 60, 60, 32)     4128
# _________________________________________________________________
# activation_20 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 4, 30, 30, 64)     16448
# _________________________________________________________________
# activation_21 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_14 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 2, 15, 15, 128)    65664
# _________________________________________________________________
# activation_22 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               802944
# _________________________________________________________________
# activation_23 (Activation)   (None, 128)               0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               33024
# _________________________________________________________________
# activation_24 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 1285
# _________________________________________________________________
# activation_25 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 925,365
# Trainable params: 924,629
# Non-trainable params: 736
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.4121 - categorical_accuracy: 0.4437
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.16000, saving model to Conv3D_2_2021-05-2412_38_25.496330/model-00001-1.40730-0.44646-1.82290-0.16000.h5
# 21/21 [==============================] - 37s 2s/step - loss: 1.4056 - categorical_accuracy: 0.4465 - val_loss: 1.8229 - val_categorical_accuracy: 0.1600
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.9157 - categorical_accuracy: 0.6516
# Epoch 00002: val_categorical_accuracy did not improve from 0.16000
# 21/21 [==============================] - 38s 2s/step - loss: 0.9098 - categorical_accuracy: 0.6516 - val_loss: 2.9138 - val_categorical_accuracy: 0.1600
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.6399 - categorical_accuracy: 0.7734
# Epoch 00003: val_categorical_accuracy improved from 0.16000 to 0.17000, saving model to Conv3D_2_2021-05-2412_38_25.496330/model-00003-0.63404-0.77225-3.81985-0.17000.h5
# 21/21 [==============================] - 36s 2s/step - loss: 0.6320 - categorical_accuracy: 0.7722 - val_loss: 3.8199 - val_categorical_accuracy: 0.1700
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5011 - categorical_accuracy: 0.8234
# Epoch 00004: val_categorical_accuracy improved from 0.17000 to 0.25000, saving model to Conv3D_2_2021-05-2412_38_25.496330/model-00004-0.50189-0.82353-4.50031-0.25000.h5
# 21/21 [==============================] - 37s 2s/step - loss: 0.5022 - categorical_accuracy: 0.8235 - val_loss: 4.5003 - val_categorical_accuracy: 0.2500
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3288 - categorical_accuracy: 0.8922
# Epoch 00005: val_categorical_accuracy did not improve from 0.25000
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 36s 2s/step - loss: 0.3249 - categorical_accuracy: 0.8944 - val_loss: 5.2566 - val_categorical_accuracy: 0.2100
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2349 - categorical_accuracy: 0.9328
# Epoch 00006: val_categorical_accuracy improved from 0.25000 to 0.29000, saving model to Conv3D_2_2021-05-2412_38_25.496330/model-00006-0.23462-0.93213-5.45417-0.29000.h5
# 21/21 [==============================] - 36s 2s/step - loss: 0.2345 - categorical_accuracy: 0.9321 - val_loss: 5.4542 - val_categorical_accuracy: 0.2900
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1856 - categorical_accuracy: 0.9563
# Epoch 00007: val_categorical_accuracy did not improve from 0.29000
# 21/21 [==============================] - 36s 2s/step - loss: 0.1835 - categorical_accuracy: 0.9548 - val_loss: 5.6526 - val_categorical_accuracy: 0.2800
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1726 - categorical_accuracy: 0.9547
# Epoch 00008: val_categorical_accuracy did not improve from 0.29000
# 21/21 [==============================] - 36s 2s/step - loss: 0.1683 - categorical_accuracy: 0.9563 - val_loss: 6.1956 - val_categorical_accuracy: 0.2500
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1220 - categorical_accuracy: 0.9750
# Epoch 00009: val_categorical_accuracy did not improve from 0.29000
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 36s 2s/step - loss: 0.1244 - categorical_accuracy: 0.9744 - val_loss: 6.0440 - val_categorical_accuracy: 0.2100
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1178 - categorical_accuracy: 0.9719
# Epoch 00010: val_categorical_accuracy did not improve from 0.29000
# 21/21 [==============================] - 36s 2s/step - loss: 0.1169 - categorical_accuracy: 0.9729 - val_loss: 6.4390 - val_categorical_accuracy: 0.2500
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0931 - categorical_accuracy: 0.9797
# Epoch 00011: val_categorical_accuracy did not improve from 0.29000
# 21/21 [==============================] - 37s 2s/step - loss: 0.0917 - categorical_accuracy: 0.9804 - val_loss: 6.5111 - val_categorical_accuracy: 0.2400
# Epoch 00011: early stopping

# %% [markdown]
# - **Model 2 is also overfitting**
# - We next try to improve upon (3,3,3)

# %% [markdown]
# ### Model Architecture 3 - Conv3D model with filter size (3,3,3) and Augmentation
# - We use augmentation and at the same time change the sequence of dense layers  - 64 followed by 128

# %%
# Model 3 - Conv3D Model with filter size (3,3,3)
def model_Conv3D_3(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(Conv3D(16, (3,3,3), 
                     input_shape = (num_frames, frame_height, frame_width, 3),     
                     padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2,2,2)))
    
    model.add(Conv3D(32, (3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(64, (3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))
    
    model.add(Conv3D(128, (3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling3D(pool_size=(2, 2, 2)))

    model.add(Flatten())

    model.add(Dense(64))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.5))
    
    model.add(Dense(128))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))
    
    # Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    
    return model

# %%
# Model 3 - Conv3D Model with filter size (3,3,3)

frame_height    = 120
frame_width     = 120
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = True
normalization   = True

model = model_Conv3D_3(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_3_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_18 (Conv3D)           (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation_26 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_19 (Conv3D)           (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_27 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_20 (Conv3D)           (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_28 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_21 (Conv3D)           (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_29 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_19 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 64)                401472
# _________________________________________________________________
# activation_30 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               8320
# _________________________________________________________________
# activation_31 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 645
# _________________________________________________________________
# activation_32 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 703,493
# Trainable params: 702,885
# Non-trainable params: 608
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 2s - loss: 1.5248 - categorical_accuracy: 0.3688
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.20000, saving model to Conv3D_3_1_2021-05-2412_48_35.298967/model-00001-1.52210-0.36727-1.70956-0.20000.h5
# 21/21 [==============================] - 48s 2s/step - loss: 1.5211 - categorical_accuracy: 0.3673 - val_loss: 1.7096 - val_categorical_accuracy: 0.2000
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.0347 - categorical_accuracy: 0.5867
# Epoch 00002: val_categorical_accuracy did not improve from 0.20000
# 21/21 [==============================] - 48s 2s/step - loss: 1.0356 - categorical_accuracy: 0.5852 - val_loss: 2.9287 - val_categorical_accuracy: 0.1900
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.8206 - categorical_accuracy: 0.6672
# Epoch 00003: val_categorical_accuracy did not improve from 0.20000
# 21/21 [==============================] - 47s 2s/step - loss: 0.8225 - categorical_accuracy: 0.6652 - val_loss: 4.4821 - val_categorical_accuracy: 0.1400
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.6456 - categorical_accuracy: 0.7563
# Epoch 00004: val_categorical_accuracy did not improve from 0.20000
# 21/21 [==============================] - 47s 2s/step - loss: 0.6451 - categorical_accuracy: 0.7564 - val_loss: 5.5140 - val_categorical_accuracy: 0.1800
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5162 - categorical_accuracy: 0.8281
# Epoch 00005: val_categorical_accuracy improved from 0.20000 to 0.21000, saving model to Conv3D_3_1_2021-05-2412_48_35.298967/model-00005-0.51332-0.82730-5.62853-0.21000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 47s 2s/step - loss: 0.5123 - categorical_accuracy: 0.8273 - val_loss: 5.6285 - val_categorical_accuracy: 0.2100
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3719 - categorical_accuracy: 0.8844
# Epoch 00006: val_categorical_accuracy did not improve from 0.21000
# 21/21 [==============================] - 47s 2s/step - loss: 0.3766 - categorical_accuracy: 0.8831 - val_loss: 5.0229 - val_categorical_accuracy: 0.2100
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2922 - categorical_accuracy: 0.9211
# Epoch 00007: val_categorical_accuracy improved from 0.21000 to 0.23000, saving model to Conv3D_3_1_2021-05-2412_48_35.298967/model-00007-0.29173-0.92157-5.20137-0.23000.h5
# 21/21 [==============================] - 47s 2s/step - loss: 0.2915 - categorical_accuracy: 0.9216 - val_loss: 5.2014 - val_categorical_accuracy: 0.2300
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2510 - categorical_accuracy: 0.9289
# Epoch 00008: val_categorical_accuracy did not improve from 0.23000
# 21/21 [==============================] - 47s 2s/step - loss: 0.2451 - categorical_accuracy: 0.9306 - val_loss: 4.5783 - val_categorical_accuracy: 0.2200
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2128 - categorical_accuracy: 0.9547
# Epoch 00009: val_categorical_accuracy did not improve from 0.23000
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 47s 2s/step - loss: 0.2120 - categorical_accuracy: 0.9555 - val_loss: 5.8067 - val_categorical_accuracy: 0.2100
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1685 - categorical_accuracy: 0.9672
# Epoch 00010: val_categorical_accuracy improved from 0.23000 to 0.27000, saving model to Conv3D_3_1_2021-05-2412_48_35.298967/model-00010-0.16963-0.96757-5.33474-0.27000.h5
# 21/21 [==============================] - 47s 2s/step - loss: 0.1700 - categorical_accuracy: 0.9676 - val_loss: 5.3347 - val_categorical_accuracy: 0.2700
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1738 - categorical_accuracy: 0.9602
# Epoch 00011: val_categorical_accuracy did not improve from 0.27000
# 21/21 [==============================] - 47s 2s/step - loss: 0.1759 - categorical_accuracy: 0.9600 - val_loss: 5.0693 - val_categorical_accuracy: 0.2300
# Epoch 00011: early stopping

# %%
# Model 4 - Conv3D Model with filter size (3,3,3) without Normalization

frame_height    = 120
frame_width     = 120
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = True
normalization   = False

model = model_Conv3D_3(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_3_2', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_22 (Conv3D)           (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation_33 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_20 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_23 (Conv3D)           (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_34 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_24 (Conv3D)           (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_35 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_22 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_25 (Conv3D)           (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_36 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                401472
# _________________________________________________________________
# activation_37 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 128)               8320
# _________________________________________________________________
# activation_38 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 5)                 645
# _________________________________________________________________
# activation_39 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 703,493
# Trainable params: 702,885
# Non-trainable params: 608
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 2s - loss: 1.6092 - categorical_accuracy: 0.3539
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.26000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00001-1.60509-0.35596-11.45775-0.26000.h5
# 21/21 [==============================] - 48s 2s/step - loss: 1.6036 - categorical_accuracy: 0.3560 - val_loss: 11.4577 - val_categorical_accuracy: 0.2600
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.2092 - categorical_accuracy: 0.5055
# Epoch 00002: val_categorical_accuracy did not improve from 0.26000
# 21/21 [==============================] - 47s 2s/step - loss: 1.2002 - categorical_accuracy: 0.5053 - val_loss: 6.0866 - val_categorical_accuracy: 0.2000
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.0053 - categorical_accuracy: 0.6031
# Epoch 00003: val_categorical_accuracy did not improve from 0.26000
# 21/21 [==============================] - 46s 2s/step - loss: 1.0056 - categorical_accuracy: 0.6026 - val_loss: 2.7031 - val_categorical_accuracy: 0.2600
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.8296 - categorical_accuracy: 0.6656
# Epoch 00004: val_categorical_accuracy improved from 0.26000 to 0.29000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00004-0.82391-0.66893-2.97485-0.29000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.8219 - categorical_accuracy: 0.6689 - val_loss: 2.9749 - val_categorical_accuracy: 0.2900
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5803 - categorical_accuracy: 0.7891
# Epoch 00005: val_categorical_accuracy improved from 0.29000 to 0.32000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00005-0.57998-0.78582-2.95676-0.32000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 0.5799 - categorical_accuracy: 0.7858 - val_loss: 2.9568 - val_categorical_accuracy: 0.3200
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5087 - categorical_accuracy: 0.8195
# Epoch 00006: val_categorical_accuracy improved from 0.32000 to 0.56000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00006-0.51727-0.81674-1.10146-0.56000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.5203 - categorical_accuracy: 0.8167 - val_loss: 1.1015 - val_categorical_accuracy: 0.5600
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.4351 - categorical_accuracy: 0.8438
# Epoch 00007: val_categorical_accuracy did not improve from 0.56000
# 21/21 [==============================] - 45s 2s/step - loss: 0.4404 - categorical_accuracy: 0.8416 - val_loss: 1.6264 - val_categorical_accuracy: 0.4300
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3225 - categorical_accuracy: 0.8891
# Epoch 00008: val_categorical_accuracy did not improve from 0.56000
# 21/21 [==============================] - 46s 2s/step - loss: 0.3301 - categorical_accuracy: 0.8869 - val_loss: 1.4713 - val_categorical_accuracy: 0.4200
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2577 - categorical_accuracy: 0.9141
# Epoch 00009: val_categorical_accuracy did not improve from 0.56000
# 21/21 [==============================] - 45s 2s/step - loss: 0.2569 - categorical_accuracy: 0.9140 - val_loss: 1.6283 - val_categorical_accuracy: 0.5100
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1994 - categorical_accuracy: 0.9352
# Epoch 00010: val_categorical_accuracy improved from 0.56000 to 0.77000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00010-0.19905-0.93514-0.56468-0.77000.h5
# 21/21 [==============================] - 47s 2s/step - loss: 0.1989 - categorical_accuracy: 0.9351 - val_loss: 0.5647 - val_categorical_accuracy: 0.7700
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1823 - categorical_accuracy: 0.9375
# Epoch 00011: val_categorical_accuracy did not improve from 0.77000
# 21/21 [==============================] - 45s 2s/step - loss: 0.1907 - categorical_accuracy: 0.9351 - val_loss: 1.0148 - val_categorical_accuracy: 0.6500
# Epoch 12/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1462 - categorical_accuracy: 0.9539
# Epoch 00012: val_categorical_accuracy did not improve from 0.77000
# 21/21 [==============================] - 46s 2s/step - loss: 0.1476 - categorical_accuracy: 0.9532 - val_loss: 0.7939 - val_categorical_accuracy: 0.7000
# Epoch 13/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1216 - categorical_accuracy: 0.9625
# Epoch 00013: val_categorical_accuracy did not improve from 0.77000
# 21/21 [==============================] - 46s 2s/step - loss: 0.1185 - categorical_accuracy: 0.9630 - val_loss: 0.7870 - val_categorical_accuracy: 0.7500
# Epoch 14/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0985 - categorical_accuracy: 0.9719
# Epoch 00014: val_categorical_accuracy did not improve from 0.77000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 46s 2s/step - loss: 0.0963 - categorical_accuracy: 0.9729 - val_loss: 0.6326 - val_categorical_accuracy: 0.7600
# Epoch 15/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0707 - categorical_accuracy: 0.9766
# Epoch 00015: val_categorical_accuracy improved from 0.77000 to 0.79000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00015-0.07019-0.97738-0.46905-0.79000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 0.0700 - categorical_accuracy: 0.9774 - val_loss: 0.4691 - val_categorical_accuracy: 0.7900
# Epoch 16/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0502 - categorical_accuracy: 0.9906
# Epoch 00016: val_categorical_accuracy did not improve from 0.79000
# 21/21 [==============================] - 46s 2s/step - loss: 0.0495 - categorical_accuracy: 0.9910 - val_loss: 1.1096 - val_categorical_accuracy: 0.7600
# Epoch 17/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0443 - categorical_accuracy: 0.9922
# Epoch 00017: val_categorical_accuracy improved from 0.79000 to 0.80000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00017-0.04337-0.99246-0.55910-0.80000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 0.0430 - categorical_accuracy: 0.9925 - val_loss: 0.5591 - val_categorical_accuracy: 0.8000
# Epoch 18/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0345 - categorical_accuracy: 0.9937
# Epoch 00018: val_categorical_accuracy improved from 0.80000 to 0.81000, saving model to Conv3D_3_2_2021-05-2412_57_27.621082/model-00018-0.03678-0.99170-0.55759-0.81000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.0376 - categorical_accuracy: 0.9917 - val_loss: 0.5576 - val_categorical_accuracy: 0.8100
# Epoch 19/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0320 - categorical_accuracy: 0.9945
# Epoch 00019: val_categorical_accuracy did not improve from 0.81000
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 46s 2s/step - loss: 0.0329 - categorical_accuracy: 0.9947 - val_loss: 0.5977 - val_categorical_accuracy: 0.8000
# Epoch 20/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0331 - categorical_accuracy: 0.9945
# Epoch 00020: val_categorical_accuracy did not improve from 0.81000
# 21/21 [==============================] - 46s 2s/step - loss: 0.0333 - categorical_accuracy: 0.9940 - val_loss: 0.8069 - val_categorical_accuracy: 0.7900

# %% [markdown]
# - Till now Model 4 - Conv3D Model with filter size (3,3,3) without Normalization with augmentation has performed the well with `86%` validation accuracy
# - Let us see if this can be further improved

# %%
# Model 5 - Conv3D Model with filter size (3,3,3) without Normalization
# This model is same as above but with SGD Optimizer
frame_height    = 120
frame_width     = 120
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = True
normalization   = False

model = model_Conv3D_3(num_frames, frame_height, frame_width)
optimiser = optimizers.SGD()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_3_3', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_26 (Conv3D)           (None, 16, 120, 120, 16)  1312
# _________________________________________________________________
# activation_40 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_24 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_27 (Conv3D)           (None, 8, 60, 60, 32)     13856
# _________________________________________________________________
# activation_41 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_25 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_28 (Conv3D)           (None, 4, 30, 30, 64)     55360
# _________________________________________________________________
# activation_42 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_26 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_29 (Conv3D)           (None, 2, 15, 15, 128)    221312
# _________________________________________________________________
# activation_43 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_27 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                401472
# _________________________________________________________________
# activation_44 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 128)               8320
# _________________________________________________________________
# activation_45 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 5)                 645
# _________________________________________________________________
# activation_46 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 703,493
# Trainable params: 702,885
# Non-trainable params: 608
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 2s - loss: 1.7874 - categorical_accuracy: 0.2773
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00001-1.76984-0.28733-4.92429-0.23000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 1.7636 - categorical_accuracy: 0.2873 - val_loss: 4.9243 - val_categorical_accuracy: 0.2300
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.4122 - categorical_accuracy: 0.4195
# Epoch 00002: val_categorical_accuracy improved from 0.23000 to 0.27000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00002-1.41201-0.41855-3.46326-0.27000.h5
# 21/21 [==============================] - 47s 2s/step - loss: 1.4119 - categorical_accuracy: 0.4186 - val_loss: 3.4633 - val_categorical_accuracy: 0.2700
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.2082 - categorical_accuracy: 0.5016
# Epoch 00003: val_categorical_accuracy did not improve from 0.27000
# 21/21 [==============================] - 45s 2s/step - loss: 1.2017 - categorical_accuracy: 0.5060 - val_loss: 2.3609 - val_categorical_accuracy: 0.2200
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.0738 - categorical_accuracy: 0.5836
# Epoch 00004: val_categorical_accuracy did not improve from 0.27000
# 21/21 [==============================] - 46s 2s/step - loss: 1.0722 - categorical_accuracy: 0.5822 - val_loss: 1.5732 - val_categorical_accuracy: 0.2600
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.9458 - categorical_accuracy: 0.6281
# Epoch 00005: val_categorical_accuracy improved from 0.27000 to 0.40000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00005-0.94634-0.62896-1.27302-0.40000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 0.9465 - categorical_accuracy: 0.6290 - val_loss: 1.2730 - val_categorical_accuracy: 0.4000
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.8168 - categorical_accuracy: 0.6922
# Epoch 00006: val_categorical_accuracy improved from 0.40000 to 0.48000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00006-0.81164-0.69457-1.24034-0.48000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.8098 - categorical_accuracy: 0.6946 - val_loss: 1.2403 - val_categorical_accuracy: 0.4800
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.7378 - categorical_accuracy: 0.7406
# Epoch 00007: val_categorical_accuracy improved from 0.48000 to 0.62000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00007-0.74124-0.73982-1.11433-0.62000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.7425 - categorical_accuracy: 0.7398 - val_loss: 1.1143 - val_categorical_accuracy: 0.6200
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.6430 - categorical_accuracy: 0.7867
# Epoch 00008: val_categorical_accuracy did not improve from 0.62000
# 21/21 [==============================] - 46s 2s/step - loss: 0.6488 - categorical_accuracy: 0.7851 - val_loss: 1.1946 - val_categorical_accuracy: 0.6000
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5553 - categorical_accuracy: 0.8219
# Epoch 00009: val_categorical_accuracy did not improve from 0.62000
# 21/21 [==============================] - 47s 2s/step - loss: 0.5525 - categorical_accuracy: 0.8228 - val_loss: 1.1322 - val_categorical_accuracy: 0.5300
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5107 - categorical_accuracy: 0.8414
# Epoch 00010: val_categorical_accuracy did not improve from 0.62000
# 21/21 [==============================] - 46s 2s/step - loss: 0.5085 - categorical_accuracy: 0.8424 - val_loss: 1.0026 - val_categorical_accuracy: 0.5800
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.4204 - categorical_accuracy: 0.8891
# Epoch 00011: val_categorical_accuracy did not improve from 0.62000
# 21/21 [==============================] - 45s 2s/step - loss: 0.4222 - categorical_accuracy: 0.8899 - val_loss: 1.1960 - val_categorical_accuracy: 0.4900
# Epoch 12/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3954 - categorical_accuracy: 0.8953
# Epoch 00012: val_categorical_accuracy did not improve from 0.62000
# 21/21 [==============================] - 46s 2s/step - loss: 0.3981 - categorical_accuracy: 0.8944 - val_loss: 1.0748 - val_categorical_accuracy: 0.5200
# Epoch 13/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3519 - categorical_accuracy: 0.9062
# Epoch 00013: val_categorical_accuracy improved from 0.62000 to 0.63000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00013-0.34901-0.90799-1.04510-0.63000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 0.3480 - categorical_accuracy: 0.9080 - val_loss: 1.0451 - val_categorical_accuracy: 0.6300
# Epoch 14/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2875 - categorical_accuracy: 0.9297
# Epoch 00014: val_categorical_accuracy did not improve from 0.63000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 [==============================] - 45s 2s/step - loss: 0.2879 - categorical_accuracy: 0.9306 - val_loss: 1.0768 - val_categorical_accuracy: 0.6000
# Epoch 15/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2512 - categorical_accuracy: 0.9477
# Epoch 00015: val_categorical_accuracy improved from 0.63000 to 0.70000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00015-0.25304-0.94646-0.91600-0.70000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.2537 - categorical_accuracy: 0.9465 - val_loss: 0.9160 - val_categorical_accuracy: 0.7000
# Epoch 16/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2210 - categorical_accuracy: 0.9609
# Epoch 00016: val_categorical_accuracy improved from 0.70000 to 0.74000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00016-0.22215-0.96154-0.65718-0.74000.h5
# 21/21 [==============================] - 46s 2s/step - loss: 0.2226 - categorical_accuracy: 0.9615 - val_loss: 0.6572 - val_categorical_accuracy: 0.7400
# Epoch 17/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2234 - categorical_accuracy: 0.9570
# Epoch 00017: val_categorical_accuracy did not improve from 0.74000
# 21/21 [==============================] - 45s 2s/step - loss: 0.2239 - categorical_accuracy: 0.9570 - val_loss: 0.6683 - val_categorical_accuracy: 0.7200
# Epoch 18/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2194 - categorical_accuracy: 0.9633
# Epoch 00018: val_categorical_accuracy did not improve from 0.74000
# 21/21 [==============================] - 46s 2s/step - loss: 0.2218 - categorical_accuracy: 0.9615 - val_loss: 0.7032 - val_categorical_accuracy: 0.7200
# Epoch 19/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1930 - categorical_accuracy: 0.9719
# Epoch 00019: val_categorical_accuracy improved from 0.74000 to 0.77000, saving model to Conv3D_3_3_2021-05-2413_13_53.629214/model-00019-0.19608-0.97059-0.60114-0.77000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 0.1972 - categorical_accuracy: 0.9706 - val_loss: 0.6011 - val_categorical_accuracy: 0.7700
# Epoch 20/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1954 - categorical_accuracy: 0.9703
# Epoch 00020: val_categorical_accuracy did not improve from 0.77000
# 21/21 [==============================] - 46s 2s/step - loss: 0.1980 - categorical_accuracy: 0.9698 - val_loss: 0.7852 - val_categorical_accuracy: 0.7200

# %%
# Model 6 - Conv3D Model with filter size (3,3,3) with augmentation without Normalization and with Framesize 100x100

frame_height    = 100
frame_width     = 100
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = True
normalization   = False

model = model_Conv3D_3(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_3_4', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_30 (Conv3D)           (None, 16, 100, 100, 16)  1312
# _________________________________________________________________
# activation_47 (Activation)   (None, 16, 100, 100, 16)  0
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 16, 100, 100, 16)  64
# _________________________________________________________________
# max_pooling3d_28 (MaxPooling (None, 8, 50, 50, 16)     0
# _________________________________________________________________
# conv3d_31 (Conv3D)           (None, 8, 50, 50, 32)     13856
# _________________________________________________________________
# activation_48 (Activation)   (None, 8, 50, 50, 32)     0
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 8, 50, 50, 32)     128
# _________________________________________________________________
# max_pooling3d_29 (MaxPooling (None, 4, 25, 25, 32)     0
# _________________________________________________________________
# conv3d_32 (Conv3D)           (None, 4, 25, 25, 64)     55360
# _________________________________________________________________
# activation_49 (Activation)   (None, 4, 25, 25, 64)     0
# _________________________________________________________________
# batch_normalization_37 (Batc (None, 4, 25, 25, 64)     256
# _________________________________________________________________
# max_pooling3d_30 (MaxPooling (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# conv3d_33 (Conv3D)           (None, 2, 12, 12, 128)    221312
# _________________________________________________________________
# activation_50 (Activation)   (None, 2, 12, 12, 128)    0
# _________________________________________________________________
# batch_normalization_38 (Batc (None, 2, 12, 12, 128)    512
# _________________________________________________________________
# max_pooling3d_31 (MaxPooling (None, 1, 6, 6, 128)      0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                294976
# _________________________________________________________________
# activation_51 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_39 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               8320
# _________________________________________________________________
# activation_52 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 5)                 645
# _________________________________________________________________
# activation_53 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 596,997
# Trainable params: 596,389
# Non-trainable params: 608
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.5732 - categorical_accuracy: 0.3617
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00001-1.56125-0.36652-22.18092-0.23000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 1.5570 - categorical_accuracy: 0.3665 - val_loss: 22.1809 - val_categorical_accuracy: 0.2300
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.2086 - categorical_accuracy: 0.5195
# Epoch 00002: val_categorical_accuracy did not improve from 0.23000
# 21/21 [==============================] - 43s 2s/step - loss: 1.2088 - categorical_accuracy: 0.5181 - val_loss: 9.9882 - val_categorical_accuracy: 0.2200
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.0871 - categorical_accuracy: 0.5602
# Epoch 00003: val_categorical_accuracy improved from 0.23000 to 0.24000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00003-1.08346-0.56259-3.39868-0.24000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 1.0822 - categorical_accuracy: 0.5626 - val_loss: 3.3987 - val_categorical_accuracy: 0.2400
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.9166 - categorical_accuracy: 0.6453
# Epoch 00004: val_categorical_accuracy improved from 0.24000 to 0.27000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00004-0.91750-0.64404-1.93732-0.27000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.9178 - categorical_accuracy: 0.6440 - val_loss: 1.9373 - val_categorical_accuracy: 0.2700
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.7893 - categorical_accuracy: 0.6930
# Epoch 00005: val_categorical_accuracy improved from 0.27000 to 0.30000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00005-0.78376-0.69457-1.75518-0.30000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.7818 - categorical_accuracy: 0.6946 - val_loss: 1.7552 - val_categorical_accuracy: 0.3000
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.6574 - categorical_accuracy: 0.7437
# Epoch 00006: val_categorical_accuracy improved from 0.30000 to 0.35000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00006-0.65908-0.74661-1.61859-0.35000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.6597 - categorical_accuracy: 0.7466 - val_loss: 1.6186 - val_categorical_accuracy: 0.3500
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5392 - categorical_accuracy: 0.8008
# Epoch 00007: val_categorical_accuracy improved from 0.35000 to 0.39000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00007-0.53603-0.80090-1.40382-0.39000.h5
# 21/21 [==============================] - 43s 2s/step - loss: 0.5349 - categorical_accuracy: 0.8009 - val_loss: 1.4038 - val_categorical_accuracy: 0.3900
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.4470 - categorical_accuracy: 0.8273
# Epoch 00008: val_categorical_accuracy improved from 0.39000 to 0.51000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00008-0.44519-0.82956-1.09504-0.51000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.4446 - categorical_accuracy: 0.8296 - val_loss: 1.0950 - val_categorical_accuracy: 0.5100
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3365 - categorical_accuracy: 0.8875
# Epoch 00009: val_categorical_accuracy improved from 0.51000 to 0.64000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00009-0.34712-0.88160-0.95343-0.64000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.3509 - categorical_accuracy: 0.8816 - val_loss: 0.9534 - val_categorical_accuracy: 0.6400
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2952 - categorical_accuracy: 0.8992
# Epoch 00010: val_categorical_accuracy improved from 0.64000 to 0.70000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00010-0.29884-0.89517-0.95230-0.70000.h5
# 21/21 [==============================] - 44s 2s/step - loss: 0.3001 - categorical_accuracy: 0.8952 - val_loss: 0.9523 - val_categorical_accuracy: 0.7000
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2777 - categorical_accuracy: 0.9062
# Epoch 00011: val_categorical_accuracy did not improve from 0.70000
# 21/21 [==============================] - 42s 2s/step - loss: 0.2770 - categorical_accuracy: 0.9057 - val_loss: 2.6627 - val_categorical_accuracy: 0.4000
# Epoch 12/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2439 - categorical_accuracy: 0.9211
# Epoch 00012: val_categorical_accuracy did not improve from 0.70000
# 21/21 [==============================] - 43s 2s/step - loss: 0.2447 - categorical_accuracy: 0.9201 - val_loss: 0.8029 - val_categorical_accuracy: 0.6300
# Epoch 13/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1892 - categorical_accuracy: 0.9383
# Epoch 00013: val_categorical_accuracy improved from 0.70000 to 0.74000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00013-0.18691-0.93967-0.53991-0.74000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.1861 - categorical_accuracy: 0.9397 - val_loss: 0.5399 - val_categorical_accuracy: 0.7400
# Epoch 14/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1266 - categorical_accuracy: 0.9586
# Epoch 00014: val_categorical_accuracy improved from 0.74000 to 0.82000, saving model to Conv3D_3_4_2021-05-2413_29_25.848730/model-00014-0.12518-0.96003-0.54350-0.82000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.1247 - categorical_accuracy: 0.9600 - val_loss: 0.5435 - val_categorical_accuracy: 0.8200
# Epoch 15/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1065 - categorical_accuracy: 0.9734
# Epoch 00015: val_categorical_accuracy did not improve from 0.82000
# 21/21 [==============================] - 43s 2s/step - loss: 0.1087 - categorical_accuracy: 0.9729 - val_loss: 0.6355 - val_categorical_accuracy: 0.7400
# Epoch 16/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0920 - categorical_accuracy: 0.9703
# Epoch 00016: val_categorical_accuracy did not improve from 0.82000
# 21/21 [==============================] - 43s 2s/step - loss: 0.0905 - categorical_accuracy: 0.9706 - val_loss: 1.3989 - val_categorical_accuracy: 0.6800
# Epoch 17/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0657 - categorical_accuracy: 0.9844
# Epoch 00017: val_categorical_accuracy did not improve from 0.82000
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 42s 2s/step - loss: 0.0645 - categorical_accuracy: 0.9849 - val_loss: 0.9243 - val_categorical_accuracy: 0.6900
# Epoch 18/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0603 - categorical_accuracy: 0.9852
# Epoch 00018: val_categorical_accuracy did not improve from 0.82000
# 21/21 [==============================] - 43s 2s/step - loss: 0.0610 - categorical_accuracy: 0.9849 - val_loss: 0.9140 - val_categorical_accuracy: 0.7300
# Epoch 19/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0393 - categorical_accuracy: 0.9914
# Epoch 00019: val_categorical_accuracy did not improve from 0.82000
# 21/21 [==============================] - 44s 2s/step - loss: 0.0392 - categorical_accuracy: 0.9917 - val_loss: 1.2125 - val_categorical_accuracy: 0.6900
# Epoch 20/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0299 - categorical_accuracy: 0.9953
# Epoch 00020: val_categorical_accuracy did not improve from 0.82000
# 21/21 [==============================] - 43s 2s/step - loss: 0.0298 - categorical_accuracy: 0.9955 - val_loss: 0.7652 - val_categorical_accuracy: 0.7800

# %%
# Model 7 - Conv3D Model with filter size (3,3,3) with augmentation without Normalization and with Framesize 100x100 and SGD Optimizer

frame_height    = 100
frame_width     = 100
num_frames      = 16
size_batch      = 32
num_epochs      = 20
augment         = True
normalization   = False

model = model_Conv3D_3(num_frames, frame_height, frame_width)
optimiser = optimizers.SGD()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_3_5', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_34 (Conv3D)           (None, 16, 100, 100, 16)  1312
# _________________________________________________________________
# activation_54 (Activation)   (None, 16, 100, 100, 16)  0
# _________________________________________________________________
# batch_normalization_40 (Batc (None, 16, 100, 100, 16)  64
# _________________________________________________________________
# max_pooling3d_32 (MaxPooling (None, 8, 50, 50, 16)     0
# _________________________________________________________________
# conv3d_35 (Conv3D)           (None, 8, 50, 50, 32)     13856
# _________________________________________________________________
# activation_55 (Activation)   (None, 8, 50, 50, 32)     0
# _________________________________________________________________
# batch_normalization_41 (Batc (None, 8, 50, 50, 32)     128
# _________________________________________________________________
# max_pooling3d_33 (MaxPooling (None, 4, 25, 25, 32)     0
# _________________________________________________________________
# conv3d_36 (Conv3D)           (None, 4, 25, 25, 64)     55360
# _________________________________________________________________
# activation_56 (Activation)   (None, 4, 25, 25, 64)     0
# _________________________________________________________________
# batch_normalization_42 (Batc (None, 4, 25, 25, 64)     256
# _________________________________________________________________
# max_pooling3d_34 (MaxPooling (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# conv3d_37 (Conv3D)           (None, 2, 12, 12, 128)    221312
# _________________________________________________________________
# activation_57 (Activation)   (None, 2, 12, 12, 128)    0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 2, 12, 12, 128)    512
# _________________________________________________________________
# max_pooling3d_35 (MaxPooling (None, 1, 6, 6, 128)      0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                294976
# _________________________________________________________________
# activation_58 (Activation)   (None, 64)                0
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               8320
# _________________________________________________________________
# activation_59 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 645
# _________________________________________________________________
# activation_60 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 596,997
# Trainable params: 596,389
# Non-trainable params: 608
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.6523 - categorical_accuracy: 0.3352
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00001-1.64862-0.33710-3.96394-0.23000.h5
# 21/21 [==============================] - 43s 2s/step - loss: 1.6473 - categorical_accuracy: 0.3371 - val_loss: 3.9639 - val_categorical_accuracy: 0.2300
# Epoch 2/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.3284 - categorical_accuracy: 0.4305
# Epoch 00002: val_categorical_accuracy did not improve from 0.23000
# 21/21 [==============================] - 44s 2s/step - loss: 1.3237 - categorical_accuracy: 0.4299 - val_loss: 3.0908 - val_categorical_accuracy: 0.2300
# Epoch 3/20
# 20/21 [===========================>..] - ETA: 1s - loss: 1.1158 - categorical_accuracy: 0.5273
# Epoch 00003: val_categorical_accuracy improved from 0.23000 to 0.24000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00003-1.11864-0.52715-2.37454-0.24000.h5
# 21/21 [==============================] - 43s 2s/step - loss: 1.1197 - categorical_accuracy: 0.5271 - val_loss: 2.3745 - val_categorical_accuracy: 0.2400
# Epoch 4/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.9584 - categorical_accuracy: 0.5938
# Epoch 00004: val_categorical_accuracy did not improve from 0.24000
# 21/21 [==============================] - 42s 2s/step - loss: 0.9501 - categorical_accuracy: 0.5965 - val_loss: 1.9674 - val_categorical_accuracy: 0.2400
# Epoch 5/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.8593 - categorical_accuracy: 0.6641
# Epoch 00005: val_categorical_accuracy did not improve from 0.24000
# 21/21 [==============================] - 42s 2s/step - loss: 0.8614 - categorical_accuracy: 0.6659 - val_loss: 2.0259 - val_categorical_accuracy: 0.2400
# Epoch 6/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.7669 - categorical_accuracy: 0.6984
# Epoch 00006: val_categorical_accuracy improved from 0.24000 to 0.40000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00006-0.76666-0.69985-1.29179-0.40000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.7666 - categorical_accuracy: 0.6998 - val_loss: 1.2918 - val_categorical_accuracy: 0.4000
# Epoch 7/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.6679 - categorical_accuracy: 0.7633
# Epoch 00007: val_categorical_accuracy improved from 0.40000 to 0.44000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00007-0.65898-0.76848-1.38773-0.44000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.6558 - categorical_accuracy: 0.7685 - val_loss: 1.3877 - val_categorical_accuracy: 0.4400
# Epoch 8/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5933 - categorical_accuracy: 0.7898
# Epoch 00008: val_categorical_accuracy improved from 0.44000 to 0.50000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00008-0.60265-0.78507-1.38010-0.50000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.6060 - categorical_accuracy: 0.7851 - val_loss: 1.3801 - val_categorical_accuracy: 0.5000
# Epoch 9/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.5012 - categorical_accuracy: 0.8328
# Epoch 00009: val_categorical_accuracy improved from 0.50000 to 0.56000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00009-0.49829-0.83484-1.07010-0.56000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.4973 - categorical_accuracy: 0.8348 - val_loss: 1.0701 - val_categorical_accuracy: 0.5600
# Epoch 10/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.4831 - categorical_accuracy: 0.8336
# Epoch 00010: val_categorical_accuracy improved from 0.56000 to 0.67000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00010-0.47964-0.83333-0.84958-0.67000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.4784 - categorical_accuracy: 0.8333 - val_loss: 0.8496 - val_categorical_accuracy: 0.6700
# Epoch 11/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3729 - categorical_accuracy: 0.8961
# Epoch 00011: val_categorical_accuracy did not improve from 0.67000
# 21/21 [==============================] - 42s 2s/step - loss: 0.3796 - categorical_accuracy: 0.8929 - val_loss: 0.9796 - val_categorical_accuracy: 0.6000
# Epoch 12/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3756 - categorical_accuracy: 0.8922
# Epoch 00012: val_categorical_accuracy did not improve from 0.67000
# 21/21 [==============================] - 42s 2s/step - loss: 0.3750 - categorical_accuracy: 0.8922 - val_loss: 1.1763 - val_categorical_accuracy: 0.4500
# Epoch 13/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3381 - categorical_accuracy: 0.9078
# Epoch 00013: val_categorical_accuracy improved from 0.67000 to 0.72000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00013-0.33445-0.91026-0.68178-0.72000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.3332 - categorical_accuracy: 0.9103 - val_loss: 0.6818 - val_categorical_accuracy: 0.7200
# Epoch 14/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2536 - categorical_accuracy: 0.9422
# Epoch 00014: val_categorical_accuracy did not improve from 0.72000
# 21/21 [==============================] - 43s 2s/step - loss: 0.2530 - categorical_accuracy: 0.9427 - val_loss: 0.8630 - val_categorical_accuracy: 0.6300
# Epoch 15/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2439 - categorical_accuracy: 0.9312
# Epoch 00015: val_categorical_accuracy did not improve from 0.72000
# 21/21 [==============================] - 42s 2s/step - loss: 0.2476 - categorical_accuracy: 0.9299 - val_loss: 0.6054 - val_categorical_accuracy: 0.7000
# Epoch 16/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2348 - categorical_accuracy: 0.9422
# Epoch 00016: val_categorical_accuracy did not improve from 0.72000
# 21/21 [==============================] - 43s 2s/step - loss: 0.2326 - categorical_accuracy: 0.9434 - val_loss: 0.5751 - val_categorical_accuracy: 0.7200
# Epoch 17/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.2050 - categorical_accuracy: 0.9609
# Epoch 00017: val_categorical_accuracy did not improve from 0.72000
# 21/21 [==============================] - 42s 2s/step - loss: 0.2067 - categorical_accuracy: 0.9600 - val_loss: 0.8045 - val_categorical_accuracy: 0.6600
# Epoch 18/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1903 - categorical_accuracy: 0.9617
# Epoch 00018: val_categorical_accuracy improved from 0.72000 to 0.74000, saving model to Conv3D_3_5_2021-05-2413_44_29.564133/model-00018-0.18846-0.96229-0.83249-0.74000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 0.1878 - categorical_accuracy: 0.9623 - val_loss: 0.8325 - val_categorical_accuracy: 0.7400
# Epoch 19/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1567 - categorical_accuracy: 0.9633
# Epoch 00019: val_categorical_accuracy did not improve from 0.74000
# 21/21 [==============================] - 42s 2s/step - loss: 0.1540 - categorical_accuracy: 0.9638 - val_loss: 0.7949 - val_categorical_accuracy: 0.7000
# Epoch 20/20
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1315 - categorical_accuracy: 0.9773
# Epoch 00020: val_categorical_accuracy did not improve from 0.74000
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 21/21 [==============================] - 43s 2s/step - loss: 0.1301 - categorical_accuracy: 0.9774 - val_loss: 0.6582 - val_categorical_accuracy: 0.7400

# %% [markdown]
# ### Model Architecture 4 - Conv3D model with filter size (3,3,3) and lesser layers
# - We use two layers of 64 filters and 1 layer of 128 filter
# - After that 512 Dense kernel is added

# %%
# Model Architecture 4 - Conv3D Model with filter size (3,3,3)
# Conv3D Filters 8, 16, 32, 64 followed by Dense layers in descending order of 256, 128 and finally 5
def model_Conv3D_4(num_frames, frame_height, frame_width):

    # Define model
    model = Sequential()

    model.add(Conv3D(8, 
                    kernel_size=(3,3,3), 
                    input_shape=(num_frames, frame_height, frame_width,3),
                    padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling3D(pool_size=(2,2,2)))

    model.add(Conv3D(16, 
                    kernel_size=(3,3,3), 
                    padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling3D(pool_size=(2,2,2)))

    model.add(Conv3D(32, 
                    kernel_size=(1,3,3), 
                    padding='same'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(MaxPooling3D(pool_size=(2,2,2)))

    model.add(Conv3D(64, 
                    kernel_size=(1,3,3), 
                    padding='same'))
    model.add(Activation('relu'))
    model.add(Dropout(0.25))

    model.add(MaxPooling3D(pool_size=(2,2,2)))

    #Flatten Layers
    model.add(Flatten())

    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.5))

    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.25))

    #softmax layer
    model.add(Dense(5, activation='softmax'))

    return model

# %%
# Model 8 - Conv3D Model with filter size (3,3,3) with augmentation without Normalization and with Framesize 100x100

frame_height    = 100
frame_width     = 100
num_frames      = 16
size_batch      = 64
num_epochs      = 20
augment         = False
normalization   = False

model = model_Conv3D_4(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_4_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalization)
modelplot(model_history)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_42 (Conv3D)           (None, 16, 100, 100, 8)   656
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 16, 100, 100, 8)   32
# _________________________________________________________________
# activation_65 (Activation)   (None, 16, 100, 100, 8)   0
# _________________________________________________________________
# max_pooling3d_40 (MaxPooling (None, 8, 50, 50, 8)      0
# _________________________________________________________________
# conv3d_43 (Conv3D)           (None, 8, 50, 50, 16)     3472
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 8, 50, 50, 16)     64
# _________________________________________________________________
# activation_66 (Activation)   (None, 8, 50, 50, 16)     0
# _________________________________________________________________
# max_pooling3d_41 (MaxPooling (None, 4, 25, 25, 16)     0
# _________________________________________________________________
# conv3d_44 (Conv3D)           (None, 4, 25, 25, 32)     4640
# _________________________________________________________________
# batch_normalization_50 (Batc (None, 4, 25, 25, 32)     128
# _________________________________________________________________
# activation_67 (Activation)   (None, 4, 25, 25, 32)     0
# _________________________________________________________________
# max_pooling3d_42 (MaxPooling (None, 2, 12, 12, 32)     0
# _________________________________________________________________
# conv3d_45 (Conv3D)           (None, 2, 12, 12, 64)     18496
# _________________________________________________________________
# activation_68 (Activation)   (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# max_pooling3d_43 (MaxPooling (None, 1, 6, 6, 64)       0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 2304)              0
# _________________________________________________________________
# dense_28 (Dense)             (None, 256)               590080
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_30 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 651,109
# Trainable params: 650,997
# Non-trainable params: 112
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 64
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 64
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 11 steps, validate for 2 steps
# Epoch 1/20
# 10/11 [==========================>...] - ETA: 2s - loss: 2.2098 - categorical_accuracy: 0.2156
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.18000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00001-2.18549-0.22021-4.22654-0.18000.h5
# 11/11 [==============================] - 32s 3s/step - loss: 2.1494 - categorical_accuracy: 0.2202 - val_loss: 4.2265 - val_categorical_accuracy: 0.1800
# Epoch 2/20
# 10/11 [==========================>...] - ETA: 3s - loss: 1.5380 - categorical_accuracy: 0.2797
# Epoch 00002: val_categorical_accuracy improved from 0.18000 to 0.19000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00002-1.53535-0.28205-3.62090-0.19000.h5
# 11/11 [==============================] - 40s 4s/step - loss: 1.5313 - categorical_accuracy: 0.2821 - val_loss: 3.6209 - val_categorical_accuracy: 0.1900
# Epoch 3/20
# 10/11 [==========================>...] - ETA: 2s - loss: 1.3470 - categorical_accuracy: 0.3938
# Epoch 00003: val_categorical_accuracy did not improve from 0.19000
# 11/11 [==============================] - 37s 3s/step - loss: 1.3458 - categorical_accuracy: 0.3891 - val_loss: 6.8948 - val_categorical_accuracy: 0.1700
# Epoch 4/20
# 10/11 [==========================>...] - ETA: 2s - loss: 1.2445 - categorical_accuracy: 0.4656
# Epoch 00004: val_categorical_accuracy improved from 0.19000 to 0.25000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00004-1.25384-0.46003-4.41185-0.25000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 1.2677 - categorical_accuracy: 0.4600 - val_loss: 4.4119 - val_categorical_accuracy: 0.2500
# Epoch 5/20
# 10/11 [==========================>...] - ETA: 2s - loss: 1.1356 - categorical_accuracy: 0.4859
# Epoch 00005: val_categorical_accuracy improved from 0.25000 to 0.27000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00005-1.13075-0.49321-4.66441-0.27000.h5
# 11/11 [==============================] - 37s 3s/step - loss: 1.1236 - categorical_accuracy: 0.4932 - val_loss: 4.6644 - val_categorical_accuracy: 0.2700
# Epoch 6/20
# 10/11 [==========================>...] - ETA: 2s - loss: 1.0816 - categorical_accuracy: 0.5281
# Epoch 00006: val_categorical_accuracy did not improve from 0.27000
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 37s 3s/step - loss: 1.0908 - categorical_accuracy: 0.5249 - val_loss: 4.4553 - val_categorical_accuracy: 0.2500
# Epoch 7/20
# 10/11 [==========================>...] - ETA: 2s - loss: 1.0347 - categorical_accuracy: 0.5469
# Epoch 00007: val_categorical_accuracy improved from 0.27000 to 0.29000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00007-1.03132-0.54902-3.51274-0.29000.h5
# 11/11 [==============================] - 37s 3s/step - loss: 1.0262 - categorical_accuracy: 0.5490 - val_loss: 3.5127 - val_categorical_accuracy: 0.2900
# Epoch 8/20
# 10/11 [==========================>...] - ETA: 3s - loss: 0.9816 - categorical_accuracy: 0.6172
# Epoch 00008: val_categorical_accuracy improved from 0.29000 to 0.32000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00008-0.97493-0.61991-2.98310-0.32000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 0.9650 - categorical_accuracy: 0.6199 - val_loss: 2.9831 - val_categorical_accuracy: 0.3200
# Epoch 9/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.9649 - categorical_accuracy: 0.5859
# Epoch 00009: val_categorical_accuracy did not improve from 0.32000
# 11/11 [==============================] - 37s 3s/step - loss: 0.9642 - categorical_accuracy: 0.5852 - val_loss: 2.8911 - val_categorical_accuracy: 0.2700
# Epoch 10/20
# 10/11 [==========================>...] - ETA: 3s - loss: 0.9256 - categorical_accuracy: 0.5969
# Epoch 00010: val_categorical_accuracy improved from 0.32000 to 0.35000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00010-0.92039-0.59879-2.48035-0.35000.h5
# 11/11 [==============================] - 40s 4s/step - loss: 0.9126 - categorical_accuracy: 0.5988 - val_loss: 2.4804 - val_categorical_accuracy: 0.3500
# Epoch 11/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.9227 - categorical_accuracy: 0.6344
# Epoch 00011: val_categorical_accuracy did not improve from 0.35000
# 11/11 [==============================] - 36s 3s/step - loss: 0.9190 - categorical_accuracy: 0.6380 - val_loss: 2.3386 - val_categorical_accuracy: 0.3100
# Epoch 12/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.8330 - categorical_accuracy: 0.6656
# Epoch 00012: val_categorical_accuracy improved from 0.35000 to 0.36000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00012-0.84071-0.66365-1.76751-0.36000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 0.8521 - categorical_accuracy: 0.6637 - val_loss: 1.7675 - val_categorical_accuracy: 0.3600
# Epoch 13/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.8487 - categorical_accuracy: 0.6484
# Epoch 00013: val_categorical_accuracy did not improve from 0.36000
# 11/11 [==============================] - 37s 3s/step - loss: 0.8542 - categorical_accuracy: 0.6440 - val_loss: 1.7936 - val_categorical_accuracy: 0.3400
# Epoch 14/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.8039 - categorical_accuracy: 0.6969
# Epoch 00014: val_categorical_accuracy improved from 0.36000 to 0.44000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00014-0.81004-0.69382-1.34589-0.44000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 0.8192 - categorical_accuracy: 0.6938 - val_loss: 1.3459 - val_categorical_accuracy: 0.4400
# Epoch 15/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.7970 - categorical_accuracy: 0.6859
# Epoch 00015: val_categorical_accuracy did not improve from 0.44000
# 11/11 [==============================] - 37s 3s/step - loss: 0.7870 - categorical_accuracy: 0.6863 - val_loss: 1.3307 - val_categorical_accuracy: 0.4200
# Epoch 16/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.8010 - categorical_accuracy: 0.6797
# Epoch 00016: val_categorical_accuracy improved from 0.44000 to 0.45000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00016-0.80229-0.67873-1.25385-0.45000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 0.8042 - categorical_accuracy: 0.6787 - val_loss: 1.2538 - val_categorical_accuracy: 0.4500
# Epoch 17/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.7362 - categorical_accuracy: 0.7047
# Epoch 00017: val_categorical_accuracy improved from 0.45000 to 0.60000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00017-0.74369-0.70136-1.01985-0.60000.h5
# 11/11 [==============================] - 37s 3s/step - loss: 0.7548 - categorical_accuracy: 0.7014 - val_loss: 1.0198 - val_categorical_accuracy: 0.6000
# Epoch 18/20
# 10/11 [==========================>...] - ETA: 3s - loss: 0.7518 - categorical_accuracy: 0.6953
# Epoch 00018: val_categorical_accuracy improved from 0.60000 to 0.65000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00018-0.75460-0.69834-0.95362-0.65000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 0.7588 - categorical_accuracy: 0.6983 - val_loss: 0.9536 - val_categorical_accuracy: 0.6500
# Epoch 19/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.7060 - categorical_accuracy: 0.7250
# Epoch 00019: val_categorical_accuracy did not improve from 0.65000
# 11/11 [==============================] - 37s 3s/step - loss: 0.6928 - categorical_accuracy: 0.7285 - val_loss: 1.0160 - val_categorical_accuracy: 0.6000
# Epoch 20/20
# 10/11 [==========================>...] - ETA: 2s - loss: 0.6767 - categorical_accuracy: 0.7234
# Epoch 00020: val_categorical_accuracy improved from 0.65000 to 0.80000, saving model to Conv3D_4_1_2021-05-2414_08_01.234134/model-00020-0.67763-0.72851-0.73751-0.80000.h5
# 11/11 [==============================] - 37s 3s/step - loss: 0.6790 - categorical_accuracy: 0.7285 - val_loss: 0.7375 - val_categorical_accuracy: 0.8000

# %% [markdown]
# - So far this is the best fit model
# - Train accuracy is 85% and validation accuracy is 81%

# %% [markdown]
# ### Model Architecture 5 -  Conv3D model with filter size (3,3,3) and Leaky ReLU
#
# - Let us improve upon the Conv3D model of filter size (3,3,3) with bit changed architecture and Dense layer of 512

# %%
# Conv3D Model with filter size (3,3,3)
def model_Conv3D_5(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(Conv3D(32,(3,3,3), strides=(1,1,1), 
              input_shape = (num_frames, frame_height, frame_width, 3),
              padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling3D(pool_size=(2,2,1),strides=(2,2,1)))

    model.add(Conv3D(64, (3,3,3), padding='same'))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))

    model.add(Conv3D(64, (3,3, 3)))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.1))
    model.add(MaxPooling3D(pool_size=(2,2,2)))
    model.add(Dropout(0.25)) # Dropout 0.5

    model.add(Flatten())
    model.add(Dropout(0.25)) # Dropout 0.25
    model.add(Dense(512))
    model.add(LeakyReLU(alpha=0.1))
# Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    return model

# %%
# Model 9 - Conv3D Model with filter size (3,3,3)
frame_height    = 100
frame_width     = 100
num_frames      = 15
size_batch      = 32
num_epochs      = 30
augment         = True
normalize       = True


model = model_Conv3D_5(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_5_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
modelplot(model_history)
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_49 (Conv3D)           (None, 15, 100, 100, 32)  2624
# _________________________________________________________________
# batch_normalization_54 (Batc (None, 15, 100, 100, 32)  128
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 15, 100, 100, 32)  0
# _________________________________________________________________
# max_pooling3d_46 (MaxPooling (None, 7, 50, 100, 32)    0
# _________________________________________________________________
# conv3d_50 (Conv3D)           (None, 7, 50, 100, 64)    55360
# _________________________________________________________________
# batch_normalization_55 (Batc (None, 7, 50, 100, 64)    256
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 7, 50, 100, 64)    0
# _________________________________________________________________
# conv3d_51 (Conv3D)           (None, 5, 48, 98, 64)     110656
# _________________________________________________________________
# batch_normalization_56 (Batc (None, 5, 48, 98, 64)     256
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 5, 48, 98, 64)     0
# _________________________________________________________________
# max_pooling3d_47 (MaxPooling (None, 2, 24, 49, 64)     0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 2, 24, 49, 64)     0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 150528)            0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 150528)            0
# _________________________________________________________________
# dense_33 (Dense)             (None, 512)               77070848
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# dense_34 (Dense)             (None, 5)                 2565
# _________________________________________________________________
# activation_70 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 77,242,693
# Trainable params: 77,242,373
# Non-trainable params: 320
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 32
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 21 steps, validate for 4 steps
# Epoch 1/30
# 20/21 [===========================>..] - ETA: 1s - loss: 101.5056 - categorical_accuracy: 0.2961
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.19000, saving model to Conv3D_5_1_2021-05-2414_23_13.677856/model-00001-98.61169-0.30166-371.57303-0.19000.h5
# 21/21 [==============================] - 45s 2s/step - loss: 97.5822 - categorical_accuracy: 0.3017 - val_loss: 371.5730 - val_categorical_accuracy: 0.1900
# Epoch 2/30
# 20/21 [===========================>..] - ETA: 1s - loss: 9.6400 - categorical_accuracy: 0.6180
# Epoch 00002: val_categorical_accuracy improved from 0.19000 to 0.26000, saving model to Conv3D_5_1_2021-05-2414_23_13.677856/model-00002-9.62895-0.61538-52.80857-0.26000.h5
# 21/21 [==============================] - 43s 2s/step - loss: 9.6250 - categorical_accuracy: 0.6154 - val_loss: 52.8086 - val_categorical_accuracy: 0.2600
# Epoch 3/30
# 20/21 [===========================>..] - ETA: 1s - loss: 3.5033 - categorical_accuracy: 0.6969
# Epoch 00003: val_categorical_accuracy improved from 0.26000 to 0.27000, saving model to Conv3D_5_1_2021-05-2414_23_13.677856/model-00003-3.47509-0.69532-13.30006-0.27000.h5
# 21/21 [==============================] - 42s 2s/step - loss: 3.4650 - categorical_accuracy: 0.6953 - val_loss: 13.3001 - val_categorical_accuracy: 0.2700
# Epoch 4/30
# 20/21 [===========================>..] - ETA: 1s - loss: 2.7537 - categorical_accuracy: 0.6961
# Epoch 00004: val_categorical_accuracy improved from 0.27000 to 0.36000, saving model to Conv3D_5_1_2021-05-2414_23_13.677856/model-00004-2.69054-0.70136-6.54880-0.36000.h5
# 21/21 [==============================] - 43s 2s/step - loss: 2.6681 - categorical_accuracy: 0.7014 - val_loss: 6.5488 - val_categorical_accuracy: 0.3600
# Epoch 5/30
# 20/21 [===========================>..] - ETA: 1s - loss: 1.7382 - categorical_accuracy: 0.7781
# Epoch 00005: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 39s 2s/step - loss: 1.6928 - categorical_accuracy: 0.7843 - val_loss: 6.6639 - val_categorical_accuracy: 0.3500
# Epoch 6/30
# 20/21 [===========================>..] - ETA: 1s - loss: 1.0000 - categorical_accuracy: 0.8359
# Epoch 00006: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 41s 2s/step - loss: 1.0062 - categorical_accuracy: 0.8363 - val_loss: 11.4198 - val_categorical_accuracy: 0.3300
# Epoch 7/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.8102 - categorical_accuracy: 0.8484
# Epoch 00007: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 42s 2s/step - loss: 0.7896 - categorical_accuracy: 0.8507 - val_loss: 11.1245 - val_categorical_accuracy: 0.2900
# Epoch 8/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.9861 - categorical_accuracy: 0.8219
# Epoch 00008: val_categorical_accuracy did not improve from 0.36000
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 21/21 [==============================] - 41s 2s/step - loss: 1.0261 - categorical_accuracy: 0.8160 - val_loss: 12.8818 - val_categorical_accuracy: 0.3000
# Epoch 9/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.3486 - categorical_accuracy: 0.9250
# Epoch 00009: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 41s 2s/step - loss: 0.3376 - categorical_accuracy: 0.9268 - val_loss: 10.6553 - val_categorical_accuracy: 0.3100
# Epoch 10/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.1845 - categorical_accuracy: 0.9430
# Epoch 00010: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 41s 2s/step - loss: 0.1799 - categorical_accuracy: 0.9427 - val_loss: 12.3724 - val_categorical_accuracy: 0.3500
# Epoch 11/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0929 - categorical_accuracy: 0.9578
# Epoch 00011: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 42s 2s/step - loss: 0.1156 - categorical_accuracy: 0.9563 - val_loss: 12.4233 - val_categorical_accuracy: 0.2500
# Epoch 12/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0440 - categorical_accuracy: 0.9828
# Epoch 00012: val_categorical_accuracy did not improve from 0.36000
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 21/21 [==============================] - 41s 2s/step - loss: 0.0464 - categorical_accuracy: 0.9819 - val_loss: 12.1084 - val_categorical_accuracy: 0.2800
# Epoch 13/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0217 - categorical_accuracy: 0.9930
# Epoch 00013: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 41s 2s/step - loss: 0.0207 - categorical_accuracy: 0.9932 - val_loss: 12.1407 - val_categorical_accuracy: 0.3100
# Epoch 14/30
# 20/21 [===========================>..] - ETA: 1s - loss: 0.0498 - categorical_accuracy: 0.9859
# Epoch 00014: val_categorical_accuracy did not improve from 0.36000
# 21/21 [==============================] - 41s 2s/step - loss: 0.0494 - categorical_accuracy: 0.9857 - val_loss: 10.0275 - val_categorical_accuracy: 0.3400
# Epoch 00014: early stopping

# %%
# Model 10 - Conv3D Model with filter size (3,3,3)
frame_height    = 100
frame_width     = 100
num_frames      = 15
size_batch      = 40
num_epochs      = 30
augment         = False
normalize       = True

model = model_Conv3D_5(num_frames, frame_height, frame_width)
optimiser = optimizers.SGD()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
pmodel_history = trainer(model, 'Conv3D_5_2', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
modelplot(model_history)
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_55 (Conv3D)           (None, 15, 100, 100, 32)  2624
# _________________________________________________________________
# batch_normalization_60 (Batc (None, 15, 100, 100, 32)  128
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 15, 100, 100, 32)  0
# _________________________________________________________________
# max_pooling3d_50 (MaxPooling (None, 7, 50, 100, 32)    0
# _________________________________________________________________
# conv3d_56 (Conv3D)           (None, 7, 50, 100, 64)    55360
# _________________________________________________________________
# batch_normalization_61 (Batc (None, 7, 50, 100, 64)    256
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 7, 50, 100, 64)    0
# _________________________________________________________________
# conv3d_57 (Conv3D)           (None, 5, 48, 98, 64)     110656
# _________________________________________________________________
# batch_normalization_62 (Batc (None, 5, 48, 98, 64)     256
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 5, 48, 98, 64)     0
# _________________________________________________________________
# max_pooling3d_51 (MaxPooling (None, 2, 24, 49, 64)     0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 2, 24, 49, 64)     0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 150528)            0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 150528)            0
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               77070848
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 5)                 2565
# _________________________________________________________________
# activation_72 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 77,242,693
# Trainable params: 77,242,373
# Non-trainable params: 320
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 40
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 40
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 17 steps, validate for 3 steps
# Epoch 1/30
# 16/17 [===========================>..] - ETA: 1s - loss: 16.9580 - categorical_accuracy: 0.2688
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.18000, saving model to Conv3D_5_2_2021-05-2414_36_22.074272/model-00001-16.43691-0.26697-12.20487-0.18000.h5
# 17/17 [==============================] - 34s 2s/step - loss: 16.0945 - categorical_accuracy: 0.2670 - val_loss: 12.2049 - val_categorical_accuracy: 0.1800
# Epoch 2/30
# 16/17 [===========================>..] - ETA: 1s - loss: 1.4972 - categorical_accuracy: 0.4469
# Epoch 00002: val_categorical_accuracy did not improve from 0.18000
# 17/17 [==============================] - 35s 2s/step - loss: 1.4803 - categorical_accuracy: 0.4510 - val_loss: 7.0687 - val_categorical_accuracy: 0.1700
# Epoch 3/30
# 16/17 [===========================>..] - ETA: 1s - loss: 1.2137 - categorical_accuracy: 0.5125
# Epoch 00003: val_categorical_accuracy improved from 0.18000 to 0.23000, saving model to Conv3D_5_2_2021-05-2414_36_22.074272/model-00003-1.21890-0.50830-2.64414-0.23000.h5
# 17/17 [==============================] - 35s 2s/step - loss: 1.2223 - categorical_accuracy: 0.5083 - val_loss: 2.6441 - val_categorical_accuracy: 0.2300
# Epoch 4/30
# 16/17 [===========================>..] - ETA: 1s - loss: 1.1034 - categorical_accuracy: 0.5344
# Epoch 00004: val_categorical_accuracy improved from 0.23000 to 0.26000, saving model to Conv3D_5_2_2021-05-2414_36_22.074272/model-00004-1.09256-0.54148-1.82614-0.26000.h5
# 17/17 [==============================] - 35s 2s/step - loss: 1.0855 - categorical_accuracy: 0.5415 - val_loss: 1.8261 - val_categorical_accuracy: 0.2600
# Epoch 5/30
# 16/17 [===========================>..] - ETA: 1s - loss: 1.0695 - categorical_accuracy: 0.5984
# Epoch 00005: val_categorical_accuracy did not improve from 0.26000
# 17/17 [==============================] - 34s 2s/step - loss: 1.0770 - categorical_accuracy: 0.5988 - val_loss: 2.7883 - val_categorical_accuracy: 0.1700
# Epoch 6/30
# 16/17 [===========================>..] - ETA: 1s - loss: 1.1056 - categorical_accuracy: 0.5766
# Epoch 00006: val_categorical_accuracy improved from 0.26000 to 0.36000, saving model to Conv3D_5_2_2021-05-2414_36_22.074272/model-00006-1.10730-0.57315-1.52368-0.36000.h5
# 17/17 [==============================] - 35s 2s/step - loss: 1.1084 - categorical_accuracy: 0.5732 - val_loss: 1.5237 - val_categorical_accuracy: 0.3600
# Epoch 7/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.7832 - categorical_accuracy: 0.6953
# Epoch 00007: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.7698 - categorical_accuracy: 0.6998 - val_loss: 1.5502 - val_categorical_accuracy: 0.3600
# Epoch 8/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.8169 - categorical_accuracy: 0.6703
# Epoch 00008: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.8007 - categorical_accuracy: 0.6772 - val_loss: 1.8813 - val_categorical_accuracy: 0.3300
# Epoch 9/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.6604 - categorical_accuracy: 0.7437
# Epoch 00009: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.6497 - categorical_accuracy: 0.7466 - val_loss: 2.5567 - val_categorical_accuracy: 0.3500
# Epoch 10/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.5600 - categorical_accuracy: 0.7906
# Epoch 00010: val_categorical_accuracy did not improve from 0.36000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 17/17 [==============================] - 35s 2s/step - loss: 0.5538 - categorical_accuracy: 0.7903 - val_loss: 2.5646 - val_categorical_accuracy: 0.3500
# Epoch 11/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.4091 - categorical_accuracy: 0.8594
# Epoch 00011: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.4218 - categorical_accuracy: 0.8552 - val_loss: 2.6229 - val_categorical_accuracy: 0.2900
# Epoch 12/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.3721 - categorical_accuracy: 0.8859
# Epoch 00012: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.3866 - categorical_accuracy: 0.8824 - val_loss: 3.0393 - val_categorical_accuracy: 0.2900
# Epoch 13/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.3425 - categorical_accuracy: 0.9047
# Epoch 00013: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.3428 - categorical_accuracy: 0.9035 - val_loss: 2.8672 - val_categorical_accuracy: 0.2900
# Epoch 14/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.3257 - categorical_accuracy: 0.9031
# Epoch 00014: val_categorical_accuracy did not improve from 0.36000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0003999999724328518.
# 17/17 [==============================] - 34s 2s/step - loss: 0.3186 - categorical_accuracy: 0.9050 - val_loss: 2.9326 - val_categorical_accuracy: 0.2900
# Epoch 15/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.3183 - categorical_accuracy: 0.9078
# Epoch 00015: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 34s 2s/step - loss: 0.3183 - categorical_accuracy: 0.9065 - val_loss: 2.8648 - val_categorical_accuracy: 0.3000
# Epoch 16/30
# 16/17 [===========================>..] - ETA: 1s - loss: 0.2997 - categorical_accuracy: 0.9187
# Epoch 00016: val_categorical_accuracy did not improve from 0.36000
# 17/17 [==============================] - 36s 2s/step - loss: 0.2939 - categorical_accuracy: 0.9216 - val_loss: 2.7859 - val_categorical_accuracy: 0.3000
# Epoch 00016: early stopping

# %%
# Model 11 - Conv3D Model with filter size (3,3,3)
frame_height    = 100
frame_width     = 100
num_frames      = 15
size_batch      = 60
num_epochs      = 30
augment         = False
normalize       = False

model = model_Conv3D_5(num_frames, frame_height, frame_width)
optimiser = optimizers.SGD()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Run the model and check accuracy
model_history = trainer(model, 'Conv3D_5_2_SGD', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
modelplot(model_history)
# Out:
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_58 (Conv3D)           (None, 15, 100, 100, 32)  2624
# _________________________________________________________________
# batch_normalization_63 (Batc (None, 15, 100, 100, 32)  128
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 15, 100, 100, 32)  0
# _________________________________________________________________
# max_pooling3d_52 (MaxPooling (None, 7, 50, 100, 32)    0
# _________________________________________________________________
# conv3d_59 (Conv3D)           (None, 7, 50, 100, 64)    55360
# _________________________________________________________________
# batch_normalization_64 (Batc (None, 7, 50, 100, 64)    256
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 7, 50, 100, 64)    0
# _________________________________________________________________
# conv3d_60 (Conv3D)           (None, 5, 48, 98, 64)     110656
# _________________________________________________________________
# batch_normalization_65 (Batc (None, 5, 48, 98, 64)     256
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 5, 48, 98, 64)     0
# _________________________________________________________________
# max_pooling3d_53 (MaxPooling (None, 2, 24, 49, 64)     0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 2, 24, 49, 64)     0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 150528)            0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 150528)            0
# _________________________________________________________________
# dense_39 (Dense)             (None, 512)               77070848
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dense_40 (Dense)             (None, 5)                 2565
# _________________________________________________________________
# activation_73 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 77,242,693
# Trainable params: 77,242,373
# Non-trainable params: 320
# _________________________________________________________________
# None
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 60
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 60
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 12 steps, validate for 2 steps
# Epoch 1/30
# 11/12 [==========================>...] - ETA: 2s - loss: 30.5380 - categorical_accuracy: 0.2424
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00001-30.42045-0.24133-407.31313-0.23000.h5
# 12/12 [==============================] - 31s 3s/step - loss: 28.5302 - categorical_accuracy: 0.2413 - val_loss: 407.3131 - val_categorical_accuracy: 0.2300
# Epoch 2/30
# 11/12 [==========================>...] - ETA: 2s - loss: 2.3448 - categorical_accuracy: 0.3758
# Epoch 00002: val_categorical_accuracy did not improve from 0.23000
# 12/12 [==============================] - 37s 3s/step - loss: 2.3220 - categorical_accuracy: 0.3741 - val_loss: 107.4562 - val_categorical_accuracy: 0.2000
# Epoch 3/30
# 11/12 [==========================>...] - ETA: 2s - loss: 1.4372 - categorical_accuracy: 0.5000
# Epoch 00003: val_categorical_accuracy did not improve from 0.23000
# 12/12 [==============================] - 34s 3s/step - loss: 1.4217 - categorical_accuracy: 0.4992 - val_loss: 51.0142 - val_categorical_accuracy: 0.2300
# Epoch 4/30
# 11/12 [==========================>...] - ETA: 2s - loss: 1.1059 - categorical_accuracy: 0.5424
# Epoch 00004: val_categorical_accuracy did not improve from 0.23000
# 12/12 [==============================] - 35s 3s/step - loss: 1.1191 - categorical_accuracy: 0.5415 - val_loss: 28.9515 - val_categorical_accuracy: 0.1400
# Epoch 5/30
# 11/12 [==========================>...] - ETA: 2s - loss: 1.1188 - categorical_accuracy: 0.5727
# Epoch 00005: val_categorical_accuracy improved from 0.23000 to 0.25000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00005-1.11870-0.57315-24.61120-0.25000.h5
# 12/12 [==============================] - 36s 3s/step - loss: 1.1164 - categorical_accuracy: 0.5732 - val_loss: 24.6112 - val_categorical_accuracy: 0.2500
# Epoch 6/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.9830 - categorical_accuracy: 0.5924
# Epoch 00006: val_categorical_accuracy did not improve from 0.25000
# 12/12 [==============================] - 35s 3s/step - loss: 0.9403 - categorical_accuracy: 0.5928 - val_loss: 14.2171 - val_categorical_accuracy: 0.2200
# Epoch 7/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.9169 - categorical_accuracy: 0.6379
# Epoch 00007: val_categorical_accuracy did not improve from 0.25000
# 12/12 [==============================] - 34s 3s/step - loss: 0.9009 - categorical_accuracy: 0.6395 - val_loss: 11.8863 - val_categorical_accuracy: 0.1800
# Epoch 8/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.8880 - categorical_accuracy: 0.6545
# Epoch 00008: val_categorical_accuracy improved from 0.25000 to 0.38000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00008-0.88998-0.65460-7.44020-0.38000.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.9217 - categorical_accuracy: 0.6546 - val_loss: 7.4402 - val_categorical_accuracy: 0.3800
# Epoch 9/30
# 11/12 [==========================>...] - ETA: 2s - loss: 1.0829 - categorical_accuracy: 0.6667
# Epoch 00009: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 34s 3s/step - loss: 1.0703 - categorical_accuracy: 0.6652 - val_loss: 4.8852 - val_categorical_accuracy: 0.3400
# Epoch 10/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.7634 - categorical_accuracy: 0.7303
# Epoch 00010: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 37s 3s/step - loss: 0.7873 - categorical_accuracy: 0.7285 - val_loss: 3.5117 - val_categorical_accuracy: 0.3400
# Epoch 11/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.7895 - categorical_accuracy: 0.7136
# Epoch 00011: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 37s 3s/step - loss: 0.7652 - categorical_accuracy: 0.7149 - val_loss: 3.8312 - val_categorical_accuracy: 0.3000
# Epoch 12/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.5878 - categorical_accuracy: 0.7939
# Epoch 00012: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 35s 3s/step - loss: 0.6131 - categorical_accuracy: 0.7934 - val_loss: 5.3813 - val_categorical_accuracy: 0.2100
# Epoch 13/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.5724 - categorical_accuracy: 0.8030
# Epoch 00013: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 34s 3s/step - loss: 0.5408 - categorical_accuracy: 0.8039 - val_loss: 2.2930 - val_categorical_accuracy: 0.3600
# Epoch 14/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.4185 - categorical_accuracy: 0.8697
# Epoch 00014: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 35s 3s/step - loss: 0.4126 - categorical_accuracy: 0.8703 - val_loss: 4.9813 - val_categorical_accuracy: 0.2700
# Epoch 15/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.4467 - categorical_accuracy: 0.8318
# Epoch 00015: val_categorical_accuracy did not improve from 0.38000
# 12/12 [==============================] - 35s 3s/step - loss: 0.4862 - categorical_accuracy: 0.8296 - val_loss: 10.0586 - val_categorical_accuracy: 0.2600
# Epoch 16/30
# 11/12 [==========================>...] - ETA: 2s - loss: 1.4251 - categorical_accuracy: 0.6864
# Epoch 00016: val_categorical_accuracy improved from 0.38000 to 0.52000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00016-1.42079-0.68778-1.82212-0.52000.h5
# 12/12 [==============================] - 36s 3s/step - loss: 1.3516 - categorical_accuracy: 0.6878 - val_loss: 1.8221 - val_categorical_accuracy: 0.5200
# Epoch 17/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.4392 - categorical_accuracy: 0.8545
# Epoch 00017: val_categorical_accuracy did not improve from 0.52000
# 12/12 [==============================] - 34s 3s/step - loss: 0.5078 - categorical_accuracy: 0.8537 - val_loss: 12.4494 - val_categorical_accuracy: 0.2200
# Epoch 18/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.5923 - categorical_accuracy: 0.8288
# Epoch 00018: val_categorical_accuracy did not improve from 0.52000
# 12/12 [==============================] - 34s 3s/step - loss: 0.5674 - categorical_accuracy: 0.8296 - val_loss: 1.8564 - val_categorical_accuracy: 0.4900
# Epoch 19/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.3726 - categorical_accuracy: 0.8742
# Epoch 00019: val_categorical_accuracy did not improve from 0.52000
# 12/12 [==============================] - 34s 3s/step - loss: 0.3767 - categorical_accuracy: 0.8733 - val_loss: 1.8166 - val_categorical_accuracy: 0.5000
# Epoch 20/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.2690 - categorical_accuracy: 0.9242
# Epoch 00020: val_categorical_accuracy did not improve from 0.52000
# 12/12 [==============================] - 35s 3s/step - loss: 0.2582 - categorical_accuracy: 0.9246 - val_loss: 1.6723 - val_categorical_accuracy: 0.4700
# Epoch 21/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.2299 - categorical_accuracy: 0.9288
# Epoch 00021: val_categorical_accuracy did not improve from 0.52000
# 12/12 [==============================] - 35s 3s/step - loss: 0.2367 - categorical_accuracy: 0.9291 - val_loss: 3.8591 - val_categorical_accuracy: 0.2600
# Epoch 22/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.4160 - categorical_accuracy: 0.8848
# Epoch 00022: val_categorical_accuracy improved from 0.52000 to 0.59000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00022-0.41426-0.88537-1.13730-0.59000.h5
# 12/12 [==============================] - 36s 3s/step - loss: 0.3860 - categorical_accuracy: 0.8854 - val_loss: 1.1373 - val_categorical_accuracy: 0.5900
# Epoch 23/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.1635 - categorical_accuracy: 0.9636
# Epoch 00023: val_categorical_accuracy did not improve from 0.59000
# 12/12 [==============================] - 34s 3s/step - loss: 0.1865 - categorical_accuracy: 0.9638 - val_loss: 1.9336 - val_categorical_accuracy: 0.5000
# Epoch 24/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.2527 - categorical_accuracy: 0.9212
# Epoch 00024: val_categorical_accuracy did not improve from 0.59000
# 12/12 [==============================] - 34s 3s/step - loss: 0.3467 - categorical_accuracy: 0.9201 - val_loss: 4.6819 - val_categorical_accuracy: 0.3000
# Epoch 25/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.9156 - categorical_accuracy: 0.8182
# Epoch 00025: val_categorical_accuracy did not improve from 0.59000
# 12/12 [==============================] - 35s 3s/step - loss: 0.8532 - categorical_accuracy: 0.8190 - val_loss: 1.0260 - val_categorical_accuracy: 0.5700
# Epoch 26/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.1732 - categorical_accuracy: 0.9591
# Epoch 00026: val_categorical_accuracy did not improve from 0.59000
# 12/12 [==============================] - 35s 3s/step - loss: 0.1671 - categorical_accuracy: 0.9593 - val_loss: 1.2167 - val_categorical_accuracy: 0.5800
# Epoch 27/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.1320 - categorical_accuracy: 0.9712
# Epoch 00027: val_categorical_accuracy did not improve from 0.59000
# 12/12 [==============================] - 35s 3s/step - loss: 0.1461 - categorical_accuracy: 0.9698 - val_loss: 2.9327 - val_categorical_accuracy: 0.4200
# Epoch 28/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.1420 - categorical_accuracy: 0.9652
# Epoch 00028: val_categorical_accuracy improved from 0.59000 to 0.61000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00028-0.14196-0.96531-1.60656-0.61000.h5
# 12/12 [==============================] - 35s 3s/step - loss: 0.1405 - categorical_accuracy: 0.9653 - val_loss: 1.6066 - val_categorical_accuracy: 0.6100
# Epoch 29/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.1344 - categorical_accuracy: 0.9727
# Epoch 00029: val_categorical_accuracy improved from 0.61000 to 0.65000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00029-0.13413-0.97285-1.01596-0.65000.h5
# 12/12 [==============================] - 37s 3s/step - loss: 0.1293 - categorical_accuracy: 0.9729 - val_loss: 1.0160 - val_categorical_accuracy: 0.6500
# Epoch 30/30
# 11/12 [==========================>...] - ETA: 2s - loss: 0.0683 - categorical_accuracy: 0.9955
# Epoch 00030: val_categorical_accuracy improved from 0.65000 to 0.66000, saving model to Conv3D_5_2_SGD_2021-05-2414_47_47.368942/model-00030-0.06808-0.99548-1.02954-0.66000.h5
# 12/12 [==============================] - 37s 3s/step - loss: 0.0643 - categorical_accuracy: 0.9955 - val_loss: 1.0295 - val_categorical_accuracy: 0.6600

# %% [markdown]
# - There is no significant improvement in above model architecture

# %% [markdown]
# ### Model Architecture 6 - CNN LSTM Model
#
# - Now let us create a LSTM model
# - Note that, so far for all the Conv3D models, we have used the Relu as activation function
# - But for LSTM models, we will use tanh as the activation function.
# - Given that ReLUs can have quite large outputs, they have traditionally been regarded as inappropriate for use with LSTMs

# %%
# CNN LSTM Model
def model_LSTM_1(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(TimeDistributed(Conv2D(16, (2, 2), padding='same'), input_shape = (num_frames, frame_height, frame_width, 3)))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(32, (2, 2), padding='same')))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(64, (2, 2), padding='same')))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(Dropout(0.2))

    model.add(TimeDistributed(Conv2D(128, (2, 2), padding='same')))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(Dropout(0.5))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(Dropout(0.5))
    
    # model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same')))
    # model.add(Activation('relu'))
    # model.add(TimeDistributed(BatchNormalization()))
    # model.add(TimeDistributed(MaxPooling2D((2, 2))))    
    # model.add(Dropout(0.5))
    
    model.add(TimeDistributed(Flatten()))
    
    model.add(LSTM(units=128, return_sequences=True, activation='tanh', recurrent_dropout=0.5))
    model.add(Dropout(0.5))
 
    model.add(LSTM(units=56, activation='tanh', recurrent_dropout=0.5))
    model.add(Dropout(0.25))
   
    # Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    
    return model

# %%
# Model 12 - CNN LSTM Model

num_frames    = 15
frame_height  = 120
frame_width   = 120
size_batch    = 84
num_epochs    = 100
augment       = False
normalize     = True

model = model_LSTM_1(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 15, 120, 120, 16)  208
# _________________________________________________________________
# activation_74 (Activation)   (None, 15, 120, 120, 16)  0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 15, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 15, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 15, 60, 60, 32)    2080
# _________________________________________________________________
# activation_75 (Activation)   (None, 15, 60, 60, 32)    0
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 15, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 15, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 15, 30, 30, 64)    8256
# _________________________________________________________________
# activation_76 (Activation)   (None, 15, 30, 30, 64)    0
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 15, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 15, 15, 15, 64)    0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 15, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 15, 15, 15, 128)   32896
# _________________________________________________________________
# activation_77 (Activation)   (None, 15, 15, 15, 128)   0
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 15, 15, 15, 128)   512
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 15, 7, 7, 128)     0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 15, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 15, 7, 7, 128)     512
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 15, 3, 3, 128)     0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 15, 3, 3, 128)     0
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 15, 1152)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 15, 128)           655872
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 15, 128)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 56)                41440
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 56)                0
# _________________________________________________________________
# dense_41 (Dense)             (None, 5)                 285
# _________________________________________________________________
# activation_78 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 742,509
# Trainable params: 741,773
# Non-trainable params: 736
# _________________________________________________________________
# None

# %%
model_history = trainer(model, 'model_LSTM_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 84
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 84
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 8 steps, validate for 2 steps
# Epoch 1/100
# 7/8 [=========================>....] - ETA: 3s - loss: 1.5477 - categorical_accuracy: 0.3265
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.18000, saving model to model_LSTM_1_2021-05-2415_07_23.179269/model-00001-1.52641-0.33333-1.60366-0.18000.h5
# 8/8 [==============================] - 33s 4s/step - loss: 1.5244 - categorical_accuracy: 0.3333 - val_loss: 1.6037 - val_categorical_accuracy: 0.1800
# Epoch 2/100
# 7/8 [=========================>....] - ETA: 4s - loss: 1.2286 - categorical_accuracy: 0.5357
# Epoch 00002: val_categorical_accuracy did not improve from 0.18000
# 8/8 [==============================] - 40s 5s/step - loss: 1.2267 - categorical_accuracy: 0.5324 - val_loss: 1.6423 - val_categorical_accuracy: 0.1800
# Epoch 3/100
# 7/8 [=========================>....] - ETA: 3s - loss: 1.0774 - categorical_accuracy: 0.5884
# Epoch 00003: val_categorical_accuracy did not improve from 0.18000
# 8/8 [==============================] - 37s 5s/step - loss: 1.0586 - categorical_accuracy: 0.5973 - val_loss: 1.6140 - val_categorical_accuracy: 0.1700
# Epoch 4/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.9349 - categorical_accuracy: 0.6463
# Epoch 00004: val_categorical_accuracy improved from 0.18000 to 0.28000, saving model to model_LSTM_1_2021-05-2415_07_23.179269/model-00004-0.94694-0.63801-1.59489-0.28000.h5
# 8/8 [==============================] - 38s 5s/step - loss: 0.9481 - categorical_accuracy: 0.6380 - val_loss: 1.5949 - val_categorical_accuracy: 0.2800
# Epoch 5/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.8739 - categorical_accuracy: 0.6616
# Epoch 00005: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 36s 5s/step - loss: 0.8580 - categorical_accuracy: 0.6682 - val_loss: 1.6000 - val_categorical_accuracy: 0.2600
# Epoch 6/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.8030 - categorical_accuracy: 0.6854
# Epoch 00006: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 38s 5s/step - loss: 0.7822 - categorical_accuracy: 0.6968 - val_loss: 1.5751 - val_categorical_accuracy: 0.2200
# Epoch 7/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.6893 - categorical_accuracy: 0.7568
# Epoch 00007: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 36s 5s/step - loss: 0.7034 - categorical_accuracy: 0.7481 - val_loss: 1.6418 - val_categorical_accuracy: 0.2300
# Epoch 8/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.6246 - categorical_accuracy: 0.7721
# Epoch 00008: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 37s 5s/step - loss: 0.6233 - categorical_accuracy: 0.7707 - val_loss: 1.5920 - val_categorical_accuracy: 0.2600
# Epoch 9/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.5704 - categorical_accuracy: 0.7874
# Epoch 00009: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 36s 5s/step - loss: 0.5793 - categorical_accuracy: 0.7828 - val_loss: 1.6354 - val_categorical_accuracy: 0.2000
# Epoch 10/100
# 7/8 [=========================>....] - ETA: 4s - loss: 0.5226 - categorical_accuracy: 0.8044
# Epoch 00010: val_categorical_accuracy did not improve from 0.28000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 8/8 [==============================] - 40s 5s/step - loss: 0.5233 - categorical_accuracy: 0.8054 - val_loss: 1.6690 - val_categorical_accuracy: 0.2700
# Epoch 11/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.4603 - categorical_accuracy: 0.8316
# Epoch 00011: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 36s 5s/step - loss: 0.4540 - categorical_accuracy: 0.8356 - val_loss: 1.6062 - val_categorical_accuracy: 0.2300
# Epoch 12/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.3902 - categorical_accuracy: 0.8622
# Epoch 00012: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 37s 5s/step - loss: 0.4013 - categorical_accuracy: 0.8582 - val_loss: 1.6672 - val_categorical_accuracy: 0.2000
# Epoch 13/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.3685 - categorical_accuracy: 0.8724
# Epoch 00013: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 37s 5s/step - loss: 0.3740 - categorical_accuracy: 0.8703 - val_loss: 1.6769 - val_categorical_accuracy: 0.2300
# Epoch 14/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.3777 - categorical_accuracy: 0.8673
# Epoch 00014: val_categorical_accuracy did not improve from 0.28000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 8/8 [==============================] - 38s 5s/step - loss: 0.3888 - categorical_accuracy: 0.8627 - val_loss: 1.6382 - val_categorical_accuracy: 0.2500
# Epoch 15/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.3710 - categorical_accuracy: 0.8673
# Epoch 00015: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 36s 5s/step - loss: 0.3656 - categorical_accuracy: 0.8703 - val_loss: 1.6310 - val_categorical_accuracy: 0.2300
# Epoch 16/100
# 7/8 [=========================>....] - ETA: 3s - loss: 0.3129 - categorical_accuracy: 0.8861
# Epoch 00016: val_categorical_accuracy did not improve from 0.28000
# 8/8 [==============================] - 38s 5s/step - loss: 0.3128 - categorical_accuracy: 0.8884 - val_loss: 1.7123 - val_categorical_accuracy: 0.2000
# Epoch 00016: early stopping

# %%
modelplot(model_history)

# %% [markdown]
# - The LSTM model performed decently with train accuracy if 92% and validation accuracy of 81%

# %% [markdown]
# ### Model Architecture 7 - CNN GRU Model
#
# - Let us try GRU instead of LSTM amd see its performace

# %%
# CNN GRU Model
def model_GRU_1(num_frames, frame_height, frame_width):

    model = Sequential()
    model.add(TimeDistributed(Conv2D(16, (2, 2), padding='same'), input_shape = (num_frames, frame_height, frame_width, 3)))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(32, (2, 2), padding='same')))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(64, (2, 2), padding='same')))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(Dropout(0.2))

    model.add(TimeDistributed(Conv2D(128, (2, 2), padding='same')))
    model.add(Activation('relu'))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(Dropout(0.25))
    model.add(TimeDistributed(BatchNormalization()))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(Dropout(0.25))    

    # model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same')))
    # model.add(Activation('relu'))
    # model.add(TimeDistributed(BatchNormalization()))
    # model.add(TimeDistributed(MaxPooling2D((2, 2))))    
    # model.add(Dropout(0.5))
    
    model.add(TimeDistributed(Flatten()))
    
    model.add(GRU(units=128, return_sequences=True, activation='tanh', recurrent_dropout=0.5))
    model.add(Dropout(0.25))
 
    model.add(GRU(units=50, activation='tanh', recurrent_dropout=0.5))
    model.add(Dropout(0.5))
    
    # Final softmax layer for the 5 classes
    model.add(Dense(5))
    model.add(Activation('softmax'))
    
    return model

# %%
# Model 13 - CNN GRU Model

num_frames = 16
frame_height = 120
frame_width = 120
size_batch = 64
num_epochs = 100
augment = False
normalize = True

model = model_GRU_1(num_frames, frame_height, frame_width)
optimiser = optimizers.Adam()
model.compile(optimizer = optimiser, loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Out:
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_15 (TimeDis (None, 16, 120, 120, 16)  208
# _________________________________________________________________
# activation_79 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_17 (TimeDis (None, 16, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_18 (TimeDis (None, 16, 60, 60, 32)    2080
# _________________________________________________________________
# activation_80 (Activation)   (None, 16, 60, 60, 32)    0
# _________________________________________________________________
# time_distributed_19 (TimeDis (None, 16, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_20 (TimeDis (None, 16, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_21 (TimeDis (None, 16, 30, 30, 64)    8256
# _________________________________________________________________
# activation_81 (Activation)   (None, 16, 30, 30, 64)    0
# _________________________________________________________________
# time_distributed_22 (TimeDis (None, 16, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_23 (TimeDis (None, 16, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_24 (TimeDis (None, 16, 15, 15, 64)    256
# _________________________________________________________________
# time_distributed_25 (TimeDis (None, 16, 7, 7, 64)      0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 16, 7, 7, 64)      0
# _________________________________________________________________
# time_distributed_26 (TimeDis (None, 16, 7, 7, 128)     32896
# _________________________________________________________________
# activation_82 (Activation)   (None, 16, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_27 (TimeDis (None, 16, 7, 7, 128)     512
# _________________________________________________________________
# time_distributed_28 (TimeDis (None, 16, 3, 3, 128)     0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 16, 3, 3, 128)     0
# _________________________________________________________________
# time_distributed_29 (TimeDis (None, 16, 3, 3, 128)     512
# _________________________________________________________________
# time_distributed_30 (TimeDis (None, 16, 1, 1, 128)     0
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 16, 1, 1, 128)     0
# _________________________________________________________________
# time_distributed_31 (TimeDis (None, 16, 128)           0
# _________________________________________________________________
# gru (GRU)                    (None, 16, 128)           99072
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 16, 128)           0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 50)                27000
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 50)                0
# _________________________________________________________________
# dense_42 (Dense)             (None, 5)                 255
# _________________________________________________________________
# activation_83 (Activation)   (None, 5)                 0
# =================================================================
# Total params: 171,495
# Trainable params: 170,631
# Non-trainable params: 864
# _________________________________________________________________
# None

# %%
# Run the model and check accuracy
model_history = trainer(model, 'model_GRU_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 64
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 64
# Image Indexes:  [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 11 steps, validate for 2 steps
# Epoch 1/100
# 10/11 [==========================>...] - ETA: 3s - loss: 1.6801 - categorical_accuracy: 0.2937
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.27000, saving model to model_GRU_1_2021-05-2415_21_10.813099/model-00001-1.67678-0.29110-1.61151-0.27000.h5
# 11/11 [==============================] - 38s 3s/step - loss: 1.6718 - categorical_accuracy: 0.2911 - val_loss: 1.6115 - val_categorical_accuracy: 0.2700
# Epoch 2/100
# 10/11 [==========================>...] - ETA: 3s - loss: 1.3847 - categorical_accuracy: 0.3969
# Epoch 00002: val_categorical_accuracy did not improve from 0.27000
# 11/11 [==============================] - 42s 4s/step - loss: 1.3820 - categorical_accuracy: 0.3997 - val_loss: 1.7612 - val_categorical_accuracy: 0.2300
# Epoch 3/100
# 10/11 [==========================>...] - ETA: 3s - loss: 1.2417 - categorical_accuracy: 0.4828
# Epoch 00003: val_categorical_accuracy did not improve from 0.27000
# 11/11 [==============================] - 39s 4s/step - loss: 1.2627 - categorical_accuracy: 0.4796 - val_loss: 1.8198 - val_categorical_accuracy: 0.2100
# Epoch 4/100
# 10/11 [==========================>...] - ETA: 3s - loss: 1.1089 - categorical_accuracy: 0.5453
# Epoch 00004: val_categorical_accuracy did not improve from 0.27000
# 11/11 [==============================] - 40s 4s/step - loss: 1.0999 - categorical_accuracy: 0.5445 - val_loss: 1.8712 - val_categorical_accuracy: 0.1900
# Epoch 5/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.9807 - categorical_accuracy: 0.5922
# Epoch 00005: val_categorical_accuracy did not improve from 0.27000
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 39s 4s/step - loss: 0.9792 - categorical_accuracy: 0.5928 - val_loss: 1.9590 - val_categorical_accuracy: 0.2100
# Epoch 6/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.9146 - categorical_accuracy: 0.6328
# Epoch 00006: val_categorical_accuracy did not improve from 0.27000
# 11/11 [==============================] - 40s 4s/step - loss: 0.9278 - categorical_accuracy: 0.6305 - val_loss: 2.0106 - val_categorical_accuracy: 0.2000
# Epoch 7/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.8107 - categorical_accuracy: 0.7031
# Epoch 00007: val_categorical_accuracy did not improve from 0.27000
# 11/11 [==============================] - 40s 4s/step - loss: 0.8160 - categorical_accuracy: 0.6998 - val_loss: 1.8682 - val_categorical_accuracy: 0.2100
# Epoch 8/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.8092 - categorical_accuracy: 0.7063
# Epoch 00008: val_categorical_accuracy did not improve from 0.27000
# 11/11 [==============================] - 40s 4s/step - loss: 0.8282 - categorical_accuracy: 0.7059 - val_loss: 1.8106 - val_categorical_accuracy: 0.1600
# Epoch 9/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.7960 - categorical_accuracy: 0.6828
# Epoch 00009: val_categorical_accuracy improved from 0.27000 to 0.30000, saving model to model_GRU_1_2021-05-2415_21_10.813099/model-00009-0.79723-0.68024-1.76496-0.30000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 40s 4s/step - loss: 0.7991 - categorical_accuracy: 0.6802 - val_loss: 1.7650 - val_categorical_accuracy: 0.3000
# Epoch 10/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.7929 - categorical_accuracy: 0.6891
# Epoch 00010: val_categorical_accuracy improved from 0.30000 to 0.32000, saving model to model_GRU_1_2021-05-2415_21_10.813099/model-00010-0.78939-0.69382-1.70194-0.32000.h5
# 11/11 [==============================] - 40s 4s/step - loss: 0.7842 - categorical_accuracy: 0.6938 - val_loss: 1.7019 - val_categorical_accuracy: 0.3200
# Epoch 11/100
# 10/11 [==========================>...] - ETA: 3s - loss: 0.7554 - categorical_accuracy: 0.7047
# Epoch 00011: val_categorical_accuracy did not improve from 0.32000
# 11/11 [==============================] - 39s 4s/step - loss: 0.7470 - categorical_accuracy: 0.7059 - val_loss: 1.7928 - val_categorical_accuracy: 0.2400
# Epoch 00011: early stopping

# %%
modelplot(model_history)

# %% [markdown]
# - Performance of the GRU model above is better than that of the LSTM (Model 12)
# model in terms of higher validation accuracy
# - Train accuracy was 98%and validation accuracy is 86%

# %% [markdown]
# ### Model Architecture 9 - VGG16 LSTM Model
#
# - Now let us try the VGG16 model

# %%
# VGG16 LSTM Model
def model_VGG16_TF_1(num_frames, frame_height, frame_width):

    num_class = 5
    
    def create_base():
        conv_base = VGG16(weights='imagenet',
                          include_top=False,
                          input_shape=(frame_height, frame_width, 3))
        count=0
        for layer in conv_base.layers:
            count = count+1
        print("num of layers in VGG16 " + str(count))
        # training the model after 140 layers
        split_at = 17
        for layer in conv_base.layers[:split_at]: layer.trainable = False
        for layer in conv_base.layers[split_at:]: layer.trainable = True
        x = GlobalAveragePooling2D()(conv_base.output)
        base_model = Model(conv_base.input, x)
        return base_model
    
    conv_base = create_base()
    
    ip = Input(shape=(num_frames, frame_height, frame_width, 3))
    t_conv = TimeDistributed(conv_base)(ip) 
    drop_l = Dropout(0.5)(t_conv)
    t_lstm1 = LSTM(units=128, return_sequences=True, activation='tanh', dropout=0.5, recurrent_dropout=0.5)(drop_l)
    
    t_lstm2 = LSTM(units=50, return_sequences=False, activation='tanh', dropout=0.5, recurrent_dropout=0.5)(t_lstm1)

    f_softmax = Dense(num_class, activation='softmax')(t_lstm2)

    model = Model(ip, f_softmax)
    
    return model

# %%
# Model 14 - VGG16 transfer Learning Model

num_frames = 15
frame_height = 120
frame_width = 120
size_batch = 50
num_epochs = 100
augment = False
normalize = True

model = model_VGG16_TF_1(num_frames, frame_height, frame_width)
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['categorical_accuracy'])
print(model.summary())
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# num of layers in VGG16 19
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 15, 120, 120, 3)] 0
# _________________________________________________________________
# time_distributed_32 (TimeDis (None, 15, 512)           14714688
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 15, 512)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 15, 128)           328192
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                35800
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 255
# =================================================================
# Total params: 15,078,935
# Trainable params: 2,724,055
# Non-trainable params: 12,354,880
# _________________________________________________________________
# None

# %%
# Run the model and check accuracy
model_history = trainer(model, 'model_VGG16_TF_1', num_epochs, size_batch, num_frames, frame_height, frame_width, augment, normalize)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.
# Source path =  ./Project_data/train ; batch size = 50
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Source path =  ./Project_data/val ; batch size = 50
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 14 steps, validate for 2 steps
# Epoch 1/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.6382 - categorical_accuracy: 0.2323
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.25000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00001-1.63981-0.23077-1.60547-0.25000.h5
# 14/14 [==============================] - 39s 3s/step - loss: 1.6437 - categorical_accuracy: 0.2308 - val_loss: 1.6055 - val_categorical_accuracy: 0.2500
# Epoch 2/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.6277 - categorical_accuracy: 0.2000
# Epoch 00002: val_categorical_accuracy improved from 0.25000 to 0.39000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00002-1.62840-0.19910-1.54054-0.39000.h5
# 14/14 [==============================] - 40s 3s/step - loss: 1.6301 - categorical_accuracy: 0.1991 - val_loss: 1.5405 - val_categorical_accuracy: 0.3900
# Epoch 3/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.6019 - categorical_accuracy: 0.2338
# Epoch 00003: val_categorical_accuracy improved from 0.39000 to 0.44000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00003-1.60058-0.23831-1.49543-0.44000.h5
# 14/14 [==============================] - 37s 3s/step - loss: 1.5972 - categorical_accuracy: 0.2383 - val_loss: 1.4954 - val_categorical_accuracy: 0.4400
# Epoch 4/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.6035 - categorical_accuracy: 0.2508
# Epoch 00004: val_categorical_accuracy did not improve from 0.44000
# 14/14 [==============================] - 38s 3s/step - loss: 1.6113 - categorical_accuracy: 0.2489 - val_loss: 1.5353 - val_categorical_accuracy: 0.3700
# Epoch 5/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.5612 - categorical_accuracy: 0.2862
# Epoch 00005: val_categorical_accuracy improved from 0.44000 to 0.55000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00005-1.55901-0.29110-1.41831-0.55000.h5
# 14/14 [==============================] - 39s 3s/step - loss: 1.5537 - categorical_accuracy: 0.2911 - val_loss: 1.4183 - val_categorical_accuracy: 0.5500
# Epoch 6/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.5345 - categorical_accuracy: 0.3015
# Epoch 00006: val_categorical_accuracy did not improve from 0.55000
# 14/14 [==============================] - 37s 3s/step - loss: 1.5363 - categorical_accuracy: 0.2986 - val_loss: 1.3569 - val_categorical_accuracy: 0.5300
# Epoch 7/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.4753 - categorical_accuracy: 0.3723
# Epoch 00007: val_categorical_accuracy did not improve from 0.55000
# 14/14 [==============================] - 37s 3s/step - loss: 1.4752 - categorical_accuracy: 0.3710 - val_loss: 1.3127 - val_categorical_accuracy: 0.4700
# Epoch 8/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.4895 - categorical_accuracy: 0.3400
# Epoch 00008: val_categorical_accuracy improved from 0.55000 to 0.56000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00008-1.48829-0.34238-1.23261-0.56000.h5
# 14/14 [==============================] - 37s 3s/step - loss: 1.4853 - categorical_accuracy: 0.3424 - val_loss: 1.2326 - val_categorical_accuracy: 0.5600
# Epoch 9/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.3764 - categorical_accuracy: 0.3938
# Epoch 00009: val_categorical_accuracy improved from 0.56000 to 0.61000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00009-1.37874-0.39367-1.15519-0.61000.h5
# 14/14 [==============================] - 37s 3s/step - loss: 1.3846 - categorical_accuracy: 0.3937 - val_loss: 1.1552 - val_categorical_accuracy: 0.6100
# Epoch 10/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.3272 - categorical_accuracy: 0.4123
# Epoch 00010: val_categorical_accuracy did not improve from 0.61000
# 14/14 [==============================] - 37s 3s/step - loss: 1.3224 - categorical_accuracy: 0.4118 - val_loss: 1.1976 - val_categorical_accuracy: 0.4900
# Epoch 11/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.3089 - categorical_accuracy: 0.4200
# Epoch 00011: val_categorical_accuracy did not improve from 0.61000
# 14/14 [==============================] - 37s 3s/step - loss: 1.3067 - categorical_accuracy: 0.4223 - val_loss: 1.1731 - val_categorical_accuracy: 0.5200
# Epoch 12/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.2280 - categorical_accuracy: 0.4662
# Epoch 00012: val_categorical_accuracy did not improve from 0.61000
# 14/14 [==============================] - 37s 3s/step - loss: 1.2165 - categorical_accuracy: 0.4706 - val_loss: 1.0273 - val_categorical_accuracy: 0.6100
# Epoch 13/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.1593 - categorical_accuracy: 0.4877
# Epoch 00013: val_categorical_accuracy did not improve from 0.61000
# 14/14 [==============================] - 39s 3s/step - loss: 1.1805 - categorical_accuracy: 0.4842 - val_loss: 1.0182 - val_categorical_accuracy: 0.5900
# Epoch 14/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.0610 - categorical_accuracy: 0.5523
# Epoch 00014: val_categorical_accuracy improved from 0.61000 to 0.68000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00014-1.06205-0.55204-0.97777-0.68000.h5
# 14/14 [==============================] - 37s 3s/step - loss: 1.0646 - categorical_accuracy: 0.5520 - val_loss: 0.9778 - val_categorical_accuracy: 0.6800
# Epoch 15/100
# 13/14 [==========================>...] - ETA: 2s - loss: 1.0577 - categorical_accuracy: 0.5662
# Epoch 00015: val_categorical_accuracy did not improve from 0.68000
# 14/14 [==============================] - 37s 3s/step - loss: 1.0579 - categorical_accuracy: 0.5671 - val_loss: 0.9972 - val_categorical_accuracy: 0.6100
# Epoch 16/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.9783 - categorical_accuracy: 0.5969
# Epoch 00016: val_categorical_accuracy improved from 0.68000 to 0.72000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00016-0.97291-0.60030-0.78015-0.72000.h5
# 14/14 [==============================] - 38s 3s/step - loss: 0.9595 - categorical_accuracy: 0.6003 - val_loss: 0.7802 - val_categorical_accuracy: 0.7200
# Epoch 17/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.8710 - categorical_accuracy: 0.6415
# Epoch 00017: val_categorical_accuracy did not improve from 0.72000
# 14/14 [==============================] - 37s 3s/step - loss: 0.8734 - categorical_accuracy: 0.6410 - val_loss: 0.9046 - val_categorical_accuracy: 0.6500
# Epoch 18/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.7807 - categorical_accuracy: 0.6831
# Epoch 00018: val_categorical_accuracy improved from 0.72000 to 0.74000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00018-0.77756-0.68477-0.71033-0.74000.h5
# 14/14 [==============================] - 37s 3s/step - loss: 0.7698 - categorical_accuracy: 0.6848 - val_loss: 0.7103 - val_categorical_accuracy: 0.7400
# Epoch 19/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.7195 - categorical_accuracy: 0.7215
# Epoch 00019: val_categorical_accuracy did not improve from 0.74000
# 14/14 [==============================] - 37s 3s/step - loss: 0.7294 - categorical_accuracy: 0.7210 - val_loss: 0.6873 - val_categorical_accuracy: 0.7200
# Epoch 20/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.7563 - categorical_accuracy: 0.7046
# Epoch 00020: val_categorical_accuracy did not improve from 0.74000
# 14/14 [==============================] - 37s 3s/step - loss: 0.7450 - categorical_accuracy: 0.7059 - val_loss: 0.8598 - val_categorical_accuracy: 0.7300
# Epoch 21/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.6083 - categorical_accuracy: 0.7631
# Epoch 00021: val_categorical_accuracy did not improve from 0.74000
# 14/14 [==============================] - 37s 3s/step - loss: 0.6285 - categorical_accuracy: 0.7617 - val_loss: 0.7099 - val_categorical_accuracy: 0.7400
# Epoch 22/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.5218 - categorical_accuracy: 0.7938
# Epoch 00022: val_categorical_accuracy did not improve from 0.74000
# 14/14 [==============================] - 38s 3s/step - loss: 0.5136 - categorical_accuracy: 0.7949 - val_loss: 0.6697 - val_categorical_accuracy: 0.7400
# Epoch 23/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.4957 - categorical_accuracy: 0.8108
# Epoch 00023: val_categorical_accuracy improved from 0.74000 to 0.77000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00023-0.49259-0.81297-0.70147-0.77000.h5
# 14/14 [==============================] - 38s 3s/step - loss: 0.4848 - categorical_accuracy: 0.8130 - val_loss: 0.7015 - val_categorical_accuracy: 0.7700
# Epoch 24/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.5372 - categorical_accuracy: 0.7923
# Epoch 00024: val_categorical_accuracy improved from 0.77000 to 0.83000, saving model to model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00024-0.52997-0.79487-0.53987-0.83000.h5
# 14/14 [==============================] - 37s 3s/step - loss: 0.5123 - categorical_accuracy: 0.7949 - val_loss: 0.5399 - val_categorical_accuracy: 0.8300
# Epoch 25/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.3801 - categorical_accuracy: 0.8462
# Epoch 00025: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 37s 3s/step - loss: 0.3734 - categorical_accuracy: 0.8446 - val_loss: 0.6445 - val_categorical_accuracy: 0.8100
# Epoch 26/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.3618 - categorical_accuracy: 0.8538
# Epoch 00026: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 37s 3s/step - loss: 0.3551 - categorical_accuracy: 0.8552 - val_loss: 0.6067 - val_categorical_accuracy: 0.8200
# Epoch 27/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.3070 - categorical_accuracy: 0.8831
# Epoch 00027: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 37s 3s/step - loss: 0.3325 - categorical_accuracy: 0.8793 - val_loss: 0.6568 - val_categorical_accuracy: 0.7700
# Epoch 28/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.2855 - categorical_accuracy: 0.8969
# Epoch 00028: val_categorical_accuracy did not improve from 0.83000
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 14/14 [==============================] - 37s 3s/step - loss: 0.2696 - categorical_accuracy: 0.8989 - val_loss: 0.7370 - val_categorical_accuracy: 0.7900
# Epoch 29/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.2243 - categorical_accuracy: 0.9231
# Epoch 00029: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 37s 3s/step - loss: 0.2224 - categorical_accuracy: 0.9231 - val_loss: 0.6946 - val_categorical_accuracy: 0.7900
# Epoch 30/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.2275 - categorical_accuracy: 0.9215
# Epoch 00030: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 37s 3s/step - loss: 0.2221 - categorical_accuracy: 0.9231 - val_loss: 0.9194 - val_categorical_accuracy: 0.7600
# Epoch 31/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.2080 - categorical_accuracy: 0.9231
# Epoch 00031: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 37s 3s/step - loss: 0.2049 - categorical_accuracy: 0.9246 - val_loss: 0.6739 - val_categorical_accuracy: 0.8200
# Epoch 32/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.1714 - categorical_accuracy: 0.9400
# Epoch 00032: val_categorical_accuracy did not improve from 0.83000
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 14/14 [==============================] - 37s 3s/step - loss: 0.1736 - categorical_accuracy: 0.9397 - val_loss: 0.7391 - val_categorical_accuracy: 0.7700
# Epoch 33/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.1647 - categorical_accuracy: 0.9431
# Epoch 00033: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 39s 3s/step - loss: 0.1572 - categorical_accuracy: 0.9442 - val_loss: 0.6617 - val_categorical_accuracy: 0.8200
# Epoch 34/100
# 13/14 [==========================>...] - ETA: 2s - loss: 0.1370 - categorical_accuracy: 0.9646
# Epoch 00034: val_categorical_accuracy did not improve from 0.83000
# 14/14 [==============================] - 39s 3s/step - loss: 0.1386 - categorical_accuracy: 0.9638 - val_loss: 0.6430 - val_categorical_accuracy: 0.8000
# Epoch 00034: early stopping

# %%
modelplot(model_history)

# %% [markdown]
# - Model has performed quite well with 98% train accuracy and 88% validation accuracy

# %% [markdown]
# # Load the winner model and Test a sample
#
# - Now that we have chosen the winner, let us load it once and use to predict the class of one random image from the validation set just see if the .h5 file is created correctly and also to see if the model works

# %%
# Load the winner model i.e. Model 8 (Conv3D) h5 file
model = load_model('./model_VGG16_TF_1_2021-05-2415_32_42.128250/model-00024-0.52997-0.79487-0.53987-0.83000.h5')

# %%
# Test the model using one random image from the validation data set

# Get one random image from validation data set
one_img = generator(val_path, val_doc, batch_size = 2, num_frames = 15, 
                    frame_height = 120, frame_width = 120, augment = False, normalize=False)
one_img_data, one_img_label = next(one_img)

# Actual Class
print('Actual Class of the Image:    ', list(one_img_label[0]).index(1))

# Predicted Class from the model
print('Predicted Class of the Image: ', np.argmax(model.predict(one_img_data), axis = 1)[0])
# Out:
# Source path =  ./Project_data/val ; batch size = 2
# Image Indexes:  [ 0  2  4  6  8 10 12 15 17 19 21 23 25 27 29]
# Actual Class of the Image:     1
# Predicted Class of the Image:  1

# %% [markdown]
# - The model has correctly predicted the class of the random image chosen
#
# - We end the experimentation now
