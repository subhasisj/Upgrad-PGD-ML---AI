# %%
import pandas as pd

# %%
df = pd.read_csv('./Data/tendulkar_ODI.csv',index_col=0)

# %%
df.head()
# Out:
#   Runs Mins  BF 4s 6s      SR Pos Dismissal Inns     Opposition      Ground  \
# 1    0    -   2  0  0       0   5    caught    2     v Pakistan  Gujranwala
# 2    0    2   2  0  0       0   5    caught    2  v New Zealand     Dunedin
# 3   36   51  39  5  0    92.3   6    caught    1  v New Zealand  Wellington
# 4   19   38  35  1  1   54.28   4    bowled    2      v England       Leeds
# 5   31   31  26  3  0  119.23   6    bowled    2      v England  Nottingham
#
#   Start Date
# 1  18-Dec-89
# 2   1-Mar-90
# 3   6-Mar-90
# 4  18-Jul-90
# 5  20-Jul-90

# %%
df.describe()
# Out:
#        Runs Mins   BF   4s   6s   SR  Pos Dismissal Inns   Opposition  \
# count   295  295  295  295  295  295  295       295  295          295
# unique  118  132  110   22    8  222    7         8    3           13
# top       1    -   11    0    0    0    2    caught    2  v Australia
# freq     16   31   11   69  231   12  190       167  154           53
#
#                Ground Start Date
# count             295        295
# unique             78        295
# top     Colombo (RPS)  15-Dec-92
# freq               17          1

# %%
df.dtypes
# Out:
# Runs          object
# Mins          object
# BF            object
# 4s            object
# 6s            object
# SR            object
# Pos           object
# Dismissal     object
# Inns          object
# Opposition    object
# Ground        object
# Start Date    object
# dtype: object

# %%
df.Runs.value_counts()
# Out:
# 1       16
# 2       14
# 0       12
# 4        9
# 21       8
#         ..
# 84       1
# 89       1
# 186*     1
# 111      1
# 122      1
# Name: Runs, Length: 118, dtype: int64

# %%
df['Runs_Cleaned'] = df.Runs.apply(lambda x : x.rstrip('*'))

# %%
df['Runs_Cleaned'].value_counts()
# Out:
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 97      1
# 90      1
# 200     1
# 84      1
# 94      1
# Name: Runs_Cleaned, Length: 107, dtype: int64

# %%
df[df['Runs_Cleaned'] == 'DNB']
# Out:
#    Runs Mins BF 4s 6s SR Pos Dismissal Inns    Opposition      Ground  \
# 9   DNB    -  -  -  -  -   -         -    2  v Bangladesh  Chandigarh
# 39  DNB    -  -  -  -  -   -         -    2    v Zimbabwe        Pune
#
#    Start Date Runs_Cleaned
# 9   25-Dec-90          DNB
# 39  25-Mar-93          DNB

# %%
df = df[~(df.Runs_Cleaned.str.contains('DNB') )]

# %%
df['Runs_Cleaned'] = df['Runs_Cleaned'].astype(int)

# %%
df.describe()
# Out:
#        Runs_Cleaned
# count    292.000000
# mean      39.448630
# std       39.933374
# min        0.000000
# 25%        7.000000
# 50%       27.500000
# 75%       62.250000
# max      200.000000

# %%
df['4s'].value_counts()
# Out:
# 0     69
# 1     37
# 2     29
# 3     25
# 4     17
# 5     16
# 9     15
# 6     14
# 8     13
# 7     13
# 10    11
# 13     8
# 12     5
# 16     4
# 15     4
# 11     4
# 14     3
# 19     2
# 17     1
# 25     1
# 20     1
# Name: 4s, dtype: int64

# %%
df['4s'] = df['4s'].astype(int)

# %%
import matplotlib.pyplot as plt
df.Runs_Cleaned.hist(bins=20)
plt.show()

# %%
df[df.]['4s'].hist(bins=20)
plt.show()
